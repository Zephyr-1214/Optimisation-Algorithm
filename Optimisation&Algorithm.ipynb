# %%
#import all the necessary libraries
from pulp import LpProblem, LpMinimize, LpVariable, lpSum, value
import pandas as pd
import numpy as np

# %% [markdown]
# Part 1: Two Stage DEA

# %%
#define a function to solve the DEA problem using PuLP
def calculate_efficiency(inputs, outputs):
    #Determine the deminsion of the problem by inspecting number of imports, outputs and DMUs
    num_dmu = inputs.shape[0]
    num_inputs = inputs.shape[1]
    num_outputs = outputs.shape[1]
    #Initiate the variables for storing the results
    efficiency_scores = np.zeros(num_dmu)

    for i in range(num_dmu):
        # create the LP problem
        model = LpProblem(f"DEA_DMU_{i}", LpMinimize)

        # define the variables
        theta = LpVariable("theta", lowBound=0)  # efficiency score
        lambdas = [LpVariable(f"lambda_{j}", lowBound=0) for j in range(num_dmu)] # efficiency weights

        # objective function: minimise the efficiency score
        model += theta

        # Constraint 1: Limit the total weighted sum of all DMU input to be less than θ times the inputs of the evaluated DMU
        for j in range(num_inputs):
            model += lpSum(lambdas[k] * inputs[k, j] for k in range(num_dmu)) <= theta * inputs[i, j]

        # Constraint 2: Ensure that the weighted sum of all DMU output is greater or equal to the evaluated DMU
        for j in range(num_outputs):
            model += lpSum(lambdas[k] * outputs[k, j] for k in range(num_dmu)) >= outputs[i, j]
        #solve the problem and store the efficiency score
        model.solve()
        efficiency_scores[i] = value(theta)

    return efficiency_scores

# %%
# read 2023 data
df_2023 = pd.read_excel("DATA.xlsx", sheet_name="2023")
# Invert the values of the Airline_CPE column
df_2023['Airline_CPE'] = 1/df_2023['Airline_CPE']

# Stage one inputs and outputs
inputs_stage1 = df_2023[['operating_expense', 'Terminal_Size']].values
outputs_stage1 = df_2023[['Total_Aircraft_Movements', 'Enplanement']].values
# Calculate stage one efficiency scores
df_2023['Airport_Efficiency'] = calculate_efficiency(inputs_stage1, outputs_stage1)

# Stage two inputs and outputs
inputs_stage2 = df_2023[['Total_Aircraft_Movements', 'Enplanement','Operation_Cost']].values
outputs_stage2 = df_2023[['On_Time_Performance_Rate','Airline_CPE']].values

# Calculate stage two efficiency scores
df_2023['Airline_Efficiency'] = calculate_efficiency(inputs_stage2, outputs_stage2)
df_2023['Overall_Efficiency'] = df_2023['Airline_Efficiency'] * df_2023['Airport_Efficiency']

# Save the results as CSV
df_2023[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency', 'Overall_Efficiency']].to_csv("dea_results_2023.csv", index=False)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0be6c8621a0f405bbe29f53095ac7319-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0be6c8621a0f405bbe29f53095ac7319-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.0244293 - largest nonzero change 2.6861018e-05 ( 0.00044586825%) - largest zero change 1.5314754e-05
# 0  Obj 0 Primal inf 10.21783 (2)
# 6  Obj 0.69302432
# Optimal - objective value 0.69299985
# Optimal objective 0.6929998467 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0635153123e24d9599c2230de452a3b5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0635153123e24d9599c2230de452a3b5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.2019113 - largest nonzero change 1.2052274e-05 ( 0.00054735511%) - largest zero change 1.1661524e-05
# 0  Obj 0 Primal inf 12.501083 (2)
# 5  Obj 0.59283494
# Optimal - objective value 0.59281696
# Optimal objective 0.5928169596 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/db52a6729cc74ef59daf414a29e6389e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/db52a6729cc74ef59daf414a29e6389e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.6058328 - largest nonzero change 2.136526e-05 ( 0.00046387399%) - largest zero change 1.3958983e-05
# 0  Obj 0 Primal inf 4.3292418 (2)
# 5  Obj 0.77499352
# Optimal - objective value 0.77497756
# Optimal objective 0.7749775586 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d221ab6e17d24b359d3bfd6c8173c618-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d221ab6e17d24b359d3bfd6c8173c618-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 4.3856299 (2)
# 7  Obj 0.35014887
# Optimal - objective value 0.35013535
# Optimal objective 0.3501353504 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2e2864628f2a4b62aefaa8953825fb07-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2e2864628f2a4b62aefaa8953825fb07-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.1515819 - largest nonzero change 1.1857294e-05 ( 0.00055109656%) - largest zero change 1.1613424e-05
# 0  Obj 0 Primal inf 1.5328771 (2)
# 5  Obj 0.30745258
# Optimal - objective value 0.30744438
# Optimal objective 0.3074443811 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2ea66675421149ddbc7b72803b95d81b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2ea66675421149ddbc7b72803b95d81b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.1047645 - largest nonzero change 2.7172243e-05 ( 0.00044509895%) - largest zero change 1.5391531e-05
# 0  Obj 0 Primal inf 1.8338325 (2)
# 8  Obj 0.38633478
# Optimal - objective value 0.38632943
# Optimal objective 0.386329425 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a47a06cdf01d4258b18e116b8e351aa1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a47a06cdf01d4258b18e116b8e351aa1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.85188983 - largest nonzero change 6.8221818e-06 ( 0.00080082911%) - largest zero change 5.9448044e-06
# 0  Obj 0 Primal inf 4.1231454 (2)
# 7  Obj 0.097504378
# Optimal - objective value 0.097501005
# Optimal objective 0.09750100516 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9acc488546454f04abea03ab3c07065a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9acc488546454f04abea03ab3c07065a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 7.5305366 - largest nonzero change 3.2695799e-05 ( 0.00043417622%) - largest zero change 1.675416e-05
# 0  Obj 0 Primal inf 1.8609596 (2)
# 5  Obj 0.20957036
# Optimal - objective value 0.20956602
# Optimal objective 0.2095660196 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2caa329d126d491d902e7f4c52face69-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2caa329d126d491d902e7f4c52face69-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 7.5305366 - largest nonzero change 3.2695799e-05 ( 0.00043417622%) - largest zero change 1.675416e-05
# 0  Obj 0 Primal inf 2.1443285 (2)
# 5  Obj 0.21796493
# Optimal - objective value 0.21795983
# Optimal objective 0.217959829 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c3f45e75b6e24b0f87112cd7d334445d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c3f45e75b6e24b0f87112cd7d334445d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.1515819 - largest nonzero change 1.1857294e-05 ( 0.00055109656%) - largest zero change 1.1613424e-05
# 0  Obj 0 Primal inf 1.5474722 (2)
# 7  Obj 0.16246321
# Optimal - objective value 0.16245906
# Optimal objective 0.162459063 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b92e3128fba549418dccc3b47cf6ce90-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b92e3128fba549418dccc3b47cf6ce90-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.75060335 - largest nonzero change 6.4297897e-06 ( 0.00085661618%) - largest zero change 5.8893183e-06
# 0  Obj 0 Primal inf 6.4385864 (2)
# 6  Obj 0.16327063
# Optimal - objective value 0.16326603
# Optimal objective 0.1632660287 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5c64b3ee19bb40aa9b59936bfbc2970b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5c64b3ee19bb40aa9b59936bfbc2970b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.75060335 - largest nonzero change 6.4297897e-06 ( 0.00085661618%) - largest zero change 5.8893183e-06
# 0  Obj 0 Primal inf 2.4337638 (2)
# 6  Obj 0.14664224
# Optimal - objective value 0.14663868
# Optimal objective 0.146638677 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3d5b67c36d8a46b095f889a238f443f3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3d5b67c36d8a46b095f889a238f443f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.1836315 - largest nonzero change 1.9729618e-05 ( 0.00047159073%) - largest zero change 1.355548e-05
# 0  Obj 0 Primal inf 5.2680478 (2)
# 5  Obj 1.0000134
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/feb31bb3ed8a4c3dbc6ca7c1fcd634a2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/feb31bb3ed8a4c3dbc6ca7c1fcd634a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.570482 - largest nonzero change 4.8346876e-05 ( 0.00041784667%) - largest zero change 2.0615188e-05
# 0  Obj 0 Primal inf 11.022406 (2)
# 5  Obj 1.0000349
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/225f1f9e40ce43a4954f214342aa1732-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/225f1f9e40ce43a4954f214342aa1732-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.4831368 (2)
# 6  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c1d3782932714a0a871161557de3b335-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c1d3782932714a0a871161557de3b335-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.7719331 (2)
# 6  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cc7876fc885641799bdd4e7df56e57eb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cc7876fc885641799bdd4e7df56e57eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.9011465 (2)
# 7  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ebaece5b2494417ca89c8c3f3aca981f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ebaece5b2494417ca89c8c3f3aca981f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 2.0382028 (2)
# 7  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/19f0af06872b4eaf85d69ab190c9c00d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/19f0af06872b4eaf85d69ab190c9c00d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.9060518 (2)
# 7  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4399d90a287449f99b3e1c3342f40a11-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4399d90a287449f99b3e1c3342f40a11-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.3170882 - largest nonzero change 1.2498479e-05 ( 0.00053940453%) - largest zero change 1.17716e-05
# 0  Obj 0 Primal inf 0.91586435 (2)
# 5  Obj 0.087443529
# Optimal - objective value 0.087440621
# Optimal objective 0.08744062057 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/29ac6ebffe1c440381df89ea95252255-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/29ac6ebffe1c440381df89ea95252255-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.2874785 - largest nonzero change 1.2383768e-05 ( 0.00054137201%) - largest zero change 1.1743302e-05
# 0  Obj 0 Primal inf 2.0223382 (2)
# 6  Obj 0.55980088
# Optimal - objective value 0.55979383
# Optimal objective 0.559793832 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4664601e7aee416ca18176e2cbe5090a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4664601e7aee416ca18176e2cbe5090a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 7.5305366 - largest nonzero change 3.2695799e-05 ( 0.00043417622%) - largest zero change 1.675416e-05
# 0  Obj 0 Primal inf 3.8954224 (2)
# 5  Obj 0.37063606
# Optimal - objective value 0.37062653
# Optimal objective 0.3706265288 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cff67c3662c14606b4a69e96273167af-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cff67c3662c14606b4a69e96273167af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.0122147 - largest nonzero change 1.5191455e-05 ( 0.00050432843%) - largest zero change 1.2435942e-05
# 0  Obj 0 Primal inf 1.4775207 (2)
# 5  Obj 0.21169775
# Optimal - objective value 0.21169174
# Optimal objective 0.2116917428 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d53feb7d1bc148588807c8799e59eb18-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d53feb7d1bc148588807c8799e59eb18-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.9333855 - largest nonzero change 1.1011984e-05 ( 0.00056956998%) - largest zero change 1.1003348e-05
# 0  Obj 0 Primal inf 1.6636339 (2)
# 5  Obj 0.28304772
# Optimal - objective value 0.28303913
# Optimal objective 0.2830391323 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a90ede18afe14df5bde251d812811d23-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a90ede18afe14df5bde251d812811d23-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.3309942 - largest nonzero change 8.6782707e-06 ( 0.00065201418%) - largest zero change 8.5505176e-06
# 0  Obj 0 Primal inf 2.4281561 (2)
# 8  Obj 0.14214068
# Optimal - objective value 0.14213529
# Optimal objective 0.1421352879 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d193473b6c4b47bb9e1ef9b1db3fdc5e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d193473b6c4b47bb9e1ef9b1db3fdc5e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.0244293 - largest nonzero change 2.6861018e-05 ( 0.00044586825%) - largest zero change 1.5314754e-05
# 0  Obj 0 Primal inf 2.281255 (2)
# 5  Obj 0.49533577
# Optimal - objective value 0.49532713
# Optimal objective 0.4953271258 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1c09fd4edc904e288744f6faf65dac89-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1c09fd4edc904e288744f6faf65dac89-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 9.1167243 - largest nonzero change 3.8840819e-05 ( 0.00042603919%) - largest zero change 1.82701e-05
# 0  Obj 0 Primal inf 1.9451359 (2)
# 7  Obj 0.48946685
# Optimal - objective value 0.48946008
# Optimal objective 0.4894600782 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d81f1103bec646f0b20e8d11862094c1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d81f1103bec646f0b20e8d11862094c1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 12.268493 - largest nonzero change 5.1051024e-05 ( 0.00041611488%) - largest zero change 2.1282286e-05
# 0  Obj 0 Primal inf 3.6150119 (2)
# 5  Obj 1.0000107
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fde5bef9797543c8a3538692aea0aeb0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fde5bef9797543c8a3538692aea0aeb0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 2.0132583 (2)
# 9  Obj 0.094970041
# Optimal - objective value 0.094966178
# Optimal objective 0.09496617791 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b650e6536c5944c5941769086270972e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b650e6536c5944c5941769086270972e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.2148637 - largest nonzero change 1.2102453e-05 ( 0.00054641975%) - largest zero change 1.1673903e-05
# 0  Obj 0 Primal inf 2.3205611 (2)
# 5  Obj 0.37627014
# Optimal - objective value 0.3762612
# Optimal objective 0.3762612036 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88cbd5fa638146c59b7f5aa66d652c8f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88cbd5fa638146c59b7f5aa66d652c8f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.0687621 - largest nonzero change 1.5324725e-05 ( 0.0014338762%) - largest zero change 1.5159024e-05
# 0  Obj 0 Primal inf 3.0968528 (2)
# 7  Obj 1.0000253
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6418f2d43b3742199e3b6164952cc50b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6418f2d43b3742199e3b6164952cc50b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.0687621 - largest nonzero change 1.5324725e-05 ( 0.0014338762%) - largest zero change 1.5159024e-05
# 0  Obj 0 Primal inf 3.0968528 (2)
# 6  Obj 0.39480835
# Optimal - objective value 0.39479703
# Optimal objective 0.3947970255 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/65e093325b4f4ee0a230f4f1cc906883-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/65e093325b4f4ee0a230f4f1cc906883-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.6475609 - largest nonzero change 2.7557513e-05 ( 0.0010408642%) - largest zero change 2.7465859e-05
# 0  Obj 0 Primal inf 0.58742379 (2)
# 6  Obj 0.087919861
# Optimal - objective value 0.087916669
# Optimal objective 0.08791666914 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/554c4f06ac0743618e63d695b07a4656-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/554c4f06ac0743618e63d695b07a4656-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.5927297 - largest nonzero change 2.7132672e-05 ( 0.0010464906%) - largest zero change 2.6917182e-05
# 0  Obj 0 Primal inf 0.58742379 (2)
# 6  Obj 0.086394102
# Optimal - objective value 0.086390931
# Optimal objective 0.0863909314 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ef9dc9d80934a448dd26b5c97414f56-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ef9dc9d80934a448dd26b5c97414f56-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.4107082 - largest nonzero change 4.8966825e-05 ( 0.00090499845%) - largest zero change 4.8604322e-05
# 0  Obj 0 Primal inf 0.33213919 (2)
# 8  Obj 0.37313839
# Optimal - objective value 0.37313128
# Optimal objective 0.3731312766 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/eda20549fb184c3b9bc73e36d4397aea-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/eda20549fb184c3b9bc73e36d4397aea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.5995715 - largest nonzero change 2.7185684e-05 ( 0.0010457756%) - largest zero change 2.6931806e-05
# 0  Obj 0 Primal inf 0.36956411 (2)
# 11  Obj 0.13240459
# Optimal - objective value 0.13240173
# Optimal objective 0.1324017302 - 11 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5d8ad2abd07d4f689dab20ee3524692d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5d8ad2abd07d4f689dab20ee3524692d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.0128151 - largest nonzero change 3.8135724e-05 ( 0.00095034838%) - largest zero change 3.7792897e-05
# 0  Obj 0 Primal inf 1.1229073 (2)
# 6  Obj 0.23342934
# Optimal - objective value 0.23342226
# Optimal objective 0.2334222596 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/935ac85570954e89bf2441e5287c32e7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/935ac85570954e89bf2441e5287c32e7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 6.8345726 - largest nonzero change 5.9999157e-05 ( 0.00087787723%) - largest zero change 5.9926598e-05
# 0  Obj 0 Primal inf 1.5683034 (2)
# 3  Obj 1.0000172
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4581dc4fe6034b49a0c927cd121329ab-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4581dc4fe6034b49a0c927cd121329ab-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.2543686 - largest nonzero change 4.7755481e-05 ( 0.00090887192%) - largest zero change 4.1782693e-05
# 0  Obj 0 Primal inf 0.89427302 (2)
# 7  Obj 0.50936009
# Optimal - objective value 0.50935088
# Optimal objective 0.50935088 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2ff84eb4a24948b79bac0b6bdab542b7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2ff84eb4a24948b79bac0b6bdab542b7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.3233871 - largest nonzero change 4.0542085e-05 ( 0.00093773897%) - largest zero change 3.9232675e-05
# 0  Obj 0 Primal inf 0.52740862 (2)
# 6  Obj 0.24193053
# Optimal - objective value 0.2419259
# Optimal objective 0.2419258986 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ae2e356e9e3a4940981b8916c552fb84-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ae2e356e9e3a4940981b8916c552fb84-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.1535276 - largest nonzero change 2.3729663e-05 ( 0.0011018973%) - largest zero change 2.3685649e-05
# 0  Obj 0 Primal inf 1.4320815 (2)
# 5  Obj 0.23309748
# ...
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.1962363 - largest nonzero change 4.7305062e-05 ( 0.00091037165%) - largest zero change 4.1623465e-05
# 0  Obj 0 Primal inf 0.75231183 (2)
# 7  Obj 0.30933728
# Optimal - objective value 0.30933081
# Optimal objective 0.3093308122 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2088dc96ddba4aacad6ba693e5f796c9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2088dc96ddba4aacad6ba693e5f796c9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.1962363 - largest nonzero change 4.7305062e-05 ( 0.00091037165%) - largest zero change 4.1623465e-05
# 0  Obj 0 Primal inf 0.71954328 (2)
# 7  Obj 0.24802767
# Optimal - objective value 0.248022
# Optimal objective 0.2480219974 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b503249fa7d04f3ba7826cf958fc466c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b503249fa7d04f3ba7826cf958fc466c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.1962363 - largest nonzero change 4.7305062e-05 ( 0.00091037165%) - largest zero change 4.1623465e-05
# 0  Obj 0 Primal inf 0.73275317 (2)
# 7  Obj 0.31100017
# Optimal - objective value 0.31099374
# Optimal objective 0.3109937389 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/caa84ec4356846e2bdd4900e1edce532-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/caa84ec4356846e2bdd4900e1edce532-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.033934 - largest nonzero change 9.253649e-05 ( 0.00083865363%) - largest zero change 9.1355967e-05
# 0  Obj 0 Primal inf 1.394606 (2)
# 5  Obj 1.0000262
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7c869e2c91a148eb8d9b9a2b6e47c4be-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7c869e2c91a148eb8d9b9a2b6e47c4be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.3435527 - largest nonzero change 4.8446494e-05 ( 0.00090663452%) - largest zero change 4.8392518e-05
# 0  Obj 0 Primal inf 1.4288852 (2)
# 6  Obj 0.49448271
# Optimal - objective value 0.49447142
# Optimal objective 0.4944714219 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/454dfbb17bcd46c3a9914dc60c195988-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/454dfbb17bcd46c3a9914dc60c195988-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.0605216 - largest nonzero change 3.07572e-05 ( 0.0010049659%) - largest zero change 3.0106599e-05
# 0  Obj 0 Primal inf 1.5253023 (2)
# 7  Obj 0.61384277
# Optimal - objective value 0.61382906
# Optimal objective 0.61382906 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/83969a65ef0f4d4090fd87b2cdd35080-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/83969a65ef0f4d4090fd87b2cdd35080-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.6538235 - largest nonzero change 5.0850522e-05 ( 0.00089940059%) - largest zero change 5.0118666e-05
# 0  Obj 0 Primal inf 0.54703005 (2)
# 6  Obj 0.59523884
# Optimal - objective value 0.59522763
# Optimal objective 0.5952276332 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2a1cc41877164d43bb2eca2c2175eb4f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2a1cc41877164d43bb2eca2c2175eb4f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.649919 - largest nonzero change 4.3072108e-05 ( 0.00092629802%) - largest zero change 4.0127067e-05
# 0  Obj 0 Primal inf 0.5056117 (2)
# 8  Obj 0.78928526
# Optimal - objective value 0.78927442
# Optimal objective 0.7892744166 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/000d4d526bb0404abf8381e06fe007f2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/000d4d526bb0404abf8381e06fe007f2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.4292959 - largest nonzero change 4.1362684e-05 ( 0.00093384332%) - largest zero change 3.9522766e-05
# 0  Obj 0 Primal inf 0.4635227 (2)
# 7  Obj 0.14961905
# Optimal - objective value 0.14961547
# Optimal objective 0.1496154735 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b06ff81b8ece4f7f9664f77c01953980-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b06ff81b8ece4f7f9664f77c01953980-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.6980292 - largest nonzero change 5.1193035e-05 ( 0.00089843406%) - largest zero change 5.0260199e-05
# 0  Obj 0 Primal inf 1.1199853 (2)
# 5  Obj 0.36424801
# Optimal - objective value 0.36423934
# Optimal objective 0.3642393426 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5c2707fe2a0a4f94b6f1e393bdb7b09c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5c2707fe2a0a4f94b6f1e393bdb7b09c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.2306343 - largest nonzero change 3.2075261e-05 ( 0.00099284714%) - largest zero change 3.161172e-05
# 0  Obj 0 Primal inf 0.42533148 (2)
# 7  Obj 0.15065324
# Optimal - objective value 0.15065
# Optimal objective 0.1506499963 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9209fad7abc140ab9e8c531faf414f4e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9209fad7abc140ab9e8c531faf414f4e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.163975 - largest nonzero change 3.9306935e-05 ( 0.00094397625%) - largest zero change 3.8796035e-05
# 0  Obj 0 Primal inf 1.6479772 (2)
# 6  Obj 0.46797289
# Optimal - objective value 0.4679611
# Optimal objective 0.4679610986 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1dea4c9671614e8abfea64d326137063-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1dea4c9671614e8abfea64d326137063-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 5.0244228 - largest nonzero change 4.5973823e-05 ( 0.00091500707%) - largest zero change 4.1152857e-05
# 0  Obj 0 Primal inf 0.63517953 (2)
# 6  Obj 0.24626759
# Optimal - objective value 0.24626237
# Optimal objective 0.2462623707 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a5329b5b3f7a4a40bbf0b4431a4555d8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a5329b5b3f7a4a40bbf0b4431a4555d8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 6.0429089 - largest nonzero change 5.3865218e-05 ( 0.00089137896%) - largest zero change 5.2714286e-05
# 0  Obj 0 Primal inf 0.92200999 (2)
# 4  Obj 0.30628043
# Optimal - objective value 0.30627315
# Optimal objective 0.306273152 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
df_2023[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency','Overall_Efficiency']]
# Out:
#                                          Hub Airport               Airline  \
# 0               Chicago Midway International Airport    SouthWest Airlines
# 1   Hartsfield-Jackson Atlanta International Airport    SouthWest Airlines
# 2                       Denver International Airport     Frontier Airlines
# 3              Dallas/Ft Worth International Airport     Frontier Airlines
# 4       Minneapolis-Saint Paul International Airport  Sun Country Airlines
# 5                                    Abudabi Airport            Air Arabia
# 6              John F. Kennedy International Airport       JetBlue Airways
# 7                            Ankara Esenboga Airport           Anadolu Jet
# 8                            Ankara Esenboga Airport      Pegasus Airlines
# 9                                 Dusseldorf Airport             Eurowings
# 10               Indira Gandhi International Airport                IndiGo
# 11               Indira Gandhi International Airport              SpiceJet
# 12                                    Geneva Airport               EasyJet
# 13                                    Dublin Airport               Ryanair
# 14                     Incheon International Airport             Air Seoul
# 15                     Incheon International Airport             Air Busan
# 16                     Incheon International Airport               Jin Air
# 17                     Incheon International Airport              Jeju Air
# 18                     Incheon International Airport        T'way Airlines
# 19                      Narita International Airport         Jetstar Japan
# 20                                    Changi Airport                 Scoot
# 21       Budapest Ferenc Liszt International Airport              Wizz Air
# 22                    HongKong International Airport            HK Express
# 23             Toronto Pearson International Airport               WestJet
# 24        Aeropuerto de Adolfo Suárez Madrid-Barajas            Air Europa
# 25                              Suvarnabhumi Airport          Thai AirAsia
# 26                                 Melbourne Airport     Jetstar Australia
# 27   Fort Lauderdale-Hollywood International Airport        Spirit Airline
# 28                            Aéroport de Paris-Orly      Transavia France
# 29            The Ninoy Aquino International Airport      Cebu Pacific Air
#
#     Airport_Efficiency  Airline_Efficiency  Overall_Efficiency
# 0             0.693000            1.000000            0.693000
# 1             0.592817            0.394797            0.234042
# 2             0.774978            0.087917            0.068133
# 3             0.350135            0.086391            0.030249
# 4             0.307444            0.373131            0.114717
# 5             0.386329            0.132402            0.051151
# 6             0.097501            0.233422            0.022759
# 7             0.209566            1.000000            0.209566
# 8             0.217960            0.509351            0.111018
# 9             0.162459            0.241926            0.039303
# 10            0.163266            0.233090            0.038056
# 11            0.146639            0.239830            0.035168
# 12            1.000000            0.255669            0.255669
# 13            1.000000            1.000000            1.000000
# 14            0.176477            1.000000            0.176477
# 15            0.176477            0.487699            0.086068
# 16            0.176477            0.309331            0.054590
# 17            0.176477            0.248022            0.043770
# 18            0.176477            0.310994            0.054883
# 19            0.087441            1.000000            0.087441
# 20            0.559794            0.494471            0.276802
# 21            0.370627            0.613829            0.227501
# 22            0.211692            0.595228            0.126005
# 23            0.283039            0.789274            0.223396
# 24            0.142135            0.149615            0.021266
# 25            0.495327            0.364239            0.180418
# 26            0.489460            0.150650            0.073737
# 27            1.000000            0.467961            0.467961
# 28            0.094966            0.246262            0.023387
# 29            0.376261            0.306273            0.115239

# %%
# read 2022 data
df_2022 = pd.read_excel("DATA.xlsx", sheet_name="2022")
df_2022['Airline_CPE'] = 1/df_2022['Airline_CPE']

# Stage 1 DEA calculation
inputs_stage1 = df_2022[['operating_expense', 'Terminal_Size']].values
outputs_stage1 = df_2022[['Total_Aircraft_Movements', 'Enplanement']].values

df_2022['Airport_Efficiency'] = calculate_efficiency(inputs_stage1, outputs_stage1)

# Stage 2 DEA calculation
inputs_stage2 = df_2022[['Total_Aircraft_Movements', 'Enplanement','Operation_Cost']].values
outputs_stage2 = df_2022[['On_Time_Performance_Rate','Airline_CPE']].values

# Calculate stage two efficiency scores
df_2022['Airline_Efficiency'] = calculate_efficiency(inputs_stage2, outputs_stage2)
df_2022['Overall_Efficiency'] = df_2022['Airline_Efficiency'] * df_2022['Airport_Efficiency']

# Save the results as CSV
df_2022[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency', 'Overall_Efficiency']].to_csv("dea_results_2022.csv", index=False)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0056396f7b6a4491b1c21b380a1f4d0c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0056396f7b6a4491b1c21b380a1f4d0c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.6581377 - largest nonzero change 2.9316055e-05 ( 0.00044030413%) - largest zero change 1.5920397e-05
# 0  Obj 0 Primal inf 18.790759 (2)
# 6  Obj 1.0000415
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8d3e1e22faf44491820a756b56e23c29-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8d3e1e22faf44491820a756b56e23c29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.4335299 - largest nonzero change 1.2949583e-05 ( 0.00053213167%) - largest zero change 1.1882885e-05
# 0  Obj 0 Primal inf 22.159438 (2)
# 6  Obj 0.57435991
# Optimal - objective value 0.57433335
# Optimal objective 0.5743333504 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f6017f433fa14a0c8ca9d0d87c954642-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f6017f433fa14a0c8ca9d0d87c954642-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 5.0903194 - largest nonzero change 2.32422e-05 ( 0.00045659611%) - largest zero change 1.4422013e-05
# 0  Obj 0 Primal inf 7.2657163 (2)
# 6  Obj 0.69681933
# Optimal - objective value 0.69679549
# Optimal objective 0.6967954865 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3c25a04f68f544cc9861ce4e5a601adb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3c25a04f68f544cc9861ce4e5a601adb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 7.5460553 (2)
# 6  Obj 0.3446172
# Optimal - objective value 0.34459536
# Optimal objective 0.3445953585 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/81639b55729e4650abeb9867652b2e29-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/81639b55729e4650abeb9867652b2e29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.3779063 - largest nonzero change 1.2734093e-05 ( 0.00053551702%) - largest zero change 1.1829725e-05
# 0  Obj 0 Primal inf 6.9229709 (2)
# 6  Obj 0.29654196
# Optimal - objective value 0.29652927
# Optimal objective 0.2965292741 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6d5a238d34be433cb9b7e7967eec18e2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6d5a238d34be433cb9b7e7967eec18e2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.2536822 - largest nonzero change 3.5497324e-05 ( 0.00043007863%) - largest zero change 1.744528e-05
# 0  Obj 0 Primal inf 2.9335864 (2)
# 7  Obj 0.36618719
# Optimal - objective value 0.36617929
# Optimal objective 0.3661792875 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1c1dc92b202f49839ff6369772257fe4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1c1dc92b202f49839ff6369772257fe4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.0236683 - largest nonzero change 7.4876654e-06 ( 0.00073145427%) - largest zero change 7.2443821e-06
# 0  Obj 0 Primal inf 7.3923521 (2)
# 7  Obj 0.07024456
# Optimal - objective value 0.070237907
# Optimal objective 0.07023790685 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/58e7a9c9d58245b4a2ea35034c32cd40-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/58e7a9c9d58245b4a2ea35034c32cd40-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.3226721 - largest nonzero change 3.5764596e-05 ( 0.00042972492%) - largest zero change 1.7511214e-05
# 0  Obj 0 Primal inf 2.6960358 (2)
# 5  Obj 0.17959813
# Optimal - objective value 0.1795931
# Optimal objective 0.1795931008 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4edb13f74a684b299de44e1724063875-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4edb13f74a684b299de44e1724063875-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.3226721 - largest nonzero change 3.5764596e-05 ( 0.00042972492%) - largest zero change 1.7511214e-05
# 0  Obj 0 Primal inf 4.2213957 (2)
# 5  Obj 0.240906
# Optimal - objective value 0.24089743
# Optimal objective 0.2408974254 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e20e311aabaf46f588e2e7ad572678e0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e20e311aabaf46f588e2e7ad572678e0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.3779063 - largest nonzero change 1.2734093e-05 ( 0.00053551702%) - largest zero change 1.1829725e-05
# 0  Obj 0 Primal inf 3.2197925 (2)
# 6  Obj 0.15952188
# Optimal - objective value 0.15951551
# Optimal objective 0.159515511 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/af70d56bc7164e1aa3c545b3e2fd0b62-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/af70d56bc7164e1aa3c545b3e2fd0b62-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.87325018 - largest nonzero change 6.9049335e-06 ( 0.00079071653%) - largest zero change 6.8586978e-06
# 0  Obj 0 Primal inf 9.0652209 (2)
# 7  Obj 0.14649317
# Optimal - objective value 0.14648794
# Optimal objective 0.1464879443 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/829f95616d444eeda583d41034b3fb9c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/829f95616d444eeda583d41034b3fb9c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.87325018 - largest nonzero change 6.9049335e-06 ( 0.00079071653%) - largest zero change 6.8586978e-06
# 0  Obj 0 Primal inf 3.7815523 (2)
# 6  Obj 0.14649316
# Optimal - objective value 0.14648794
# Optimal objective 0.1464879443 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f33138f9c105474eb0467319b8730826-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f33138f9c105474eb0467319b8730826-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.6237067 - largest nonzero change 2.1434505e-05 ( 0.00046357839%) - largest zero change 1.3976065e-05
# 0  Obj 0 Primal inf 10.790385 (2)
# 5  Obj 1.0000197
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c68a76a23a124019976cf6ab02ec3dee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c68a76a23a124019976cf6ab02ec3dee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.854493 - largest nonzero change 4.9447155e-05 ( 0.00041711742%) - largest zero change 2.0886621e-05
# 0  Obj 0 Primal inf 14.876567 (2)
# 6  Obj 1.0000374
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6dc16047a3074927a01ae2a97ce3a558-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6dc16047a3074927a01ae2a97ce3a558-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 1.2887257 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/38372368a1d345b2b36ab041faeedfd9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/38372368a1d345b2b36ab041faeedfd9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 1.8101683 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b9c82d1fa0f64086b54f78cf41ee6e6d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b9c82d1fa0f64086b54f78cf41ee6e6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 2.0138833 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/94dad92d78774cafa3b3d44f8e21b09a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/94dad92d78774cafa3b3d44f8e21b09a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 2.1410492 (2)
# 8  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d91c6bfc974444d3a1e5c1fb113cb1ce-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d91c6bfc974444d3a1e5c1fb113cb1ce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 1.8831999 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b4a59163146a4efdab9afef254c25f29-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b4a59163146a4efdab9afef254c25f29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.5608222 - largest nonzero change 1.3442724e-05 ( 0.00052493781%) - largest zero change 1.200454e-05
# 0  Obj 0 Primal inf 1.2602406 (2)
# 6  Obj 0.089766423
# Optimal - objective value 0.089762283
# Optimal objective 0.08976228302 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/06b5768b18454b22ab1d39f55c98e14c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/06b5768b18454b22ab1d39f55c98e14c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.5935094 - largest nonzero change 2.1317518e-05 ( 0.00046407913%) - largest zero change 1.3947205e-05
# 0  Obj 0 Primal inf 2.4799394 (2)
# 7  Obj 0.38453915
# Optimal - objective value 0.38453164
# Optimal objective 0.384531644 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d733099ada4e48338b9d1d63f89ad7af-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d733099ada4e48338b9d1d63f89ad7af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.3226721 - largest nonzero change 3.5764596e-05 ( 0.00042972492%) - largest zero change 1.7511214e-05
# 0  Obj 0 Primal inf 4.5273562 (2)
# 5  Obj 0.33312871
# Optimal - objective value 0.33312014
# Optimal objective 0.3331201423 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/110c0226d3a748299893da0364c9bacc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/110c0226d3a748299893da0364c9bacc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.3290689 - largest nonzero change 1.6418974e-05 ( 0.00049320018%) - largest zero change 1.2738763e-05
# 0  Obj 0 Primal inf 1.004552 (2)
# 6  Obj 0.10872938
# Optimal - objective value 0.10872423
# Optimal objective 0.1087242289 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/feb52445c15043a9b84693bf126f35ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/feb52445c15043a9b84693bf126f35ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.9565443 - largest nonzero change 1.4975783e-05 ( 0.00050652998%) - largest zero change 1.2382737e-05
# 0  Obj 0 Primal inf 2.2457217 (2)
# 6  Obj 0.31942462
# Optimal - objective value 0.31941171
# Optimal objective 0.3194117141 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/943a2da844484e5998d13852f60b783b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/943a2da844484e5998d13852f60b783b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.377007 - largest nonzero change 8.8565283e-06 ( 0.00064317233%) - largest zero change 8.8016456e-06
# 0  Obj 0 Primal inf 4.1003095 (2)
# 7  Obj 0.12361996
# Optimal - objective value 0.123612
# Optimal objective 0.1236119988 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a334311184964af4892d1b67c74e0005-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a334311184964af4892d1b67c74e0005-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.6581377 - largest nonzero change 2.9316055e-05 ( 0.00044030413%) - largest zero change 1.5920397e-05
# 0  Obj 0 Primal inf 2.722036 (2)
# 8  Obj 0.353109
# Optimal - objective value 0.35309901
# Optimal objective 0.3530990087 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/941c87b87abd412293fcfcba8457ab31-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/941c87b87abd412293fcfcba8457ab31-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 13.27957 - largest nonzero change 5.4968021e-05 ( 0.00041392921%) - largest zero change 2.2248586e-05
# 0  Obj 0 Primal inf 2.4445741 (2)
# 5  Obj 0.19655582
# Optimal - objective value 0.19654986
# Optimal objective 0.1965498636 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/26205a3a982e40548e7205561b941fbe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/26205a3a982e40548e7205561b941fbe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 14.724211 - largest nonzero change 6.0564677e-05 ( 0.00041132713%) - largest zero change 2.3629248e-05
# 0  Obj 0 Primal inf 7.1103941 (2)
# 5  Obj 1.0000167
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b018e9a83a3c445594135a5264e70d2f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b018e9a83a3c445594135a5264e70d2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 3.7540063 (2)
# 8  Obj 0.094066082
# Optimal - objective value 0.09405988
# Optimal objective 0.09405987996 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/84ffa6fd4e11490793d070ee72683118-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/84ffa6fd4e11490793d070ee72683118-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.4478447 - largest nonzero change 1.300504e-05 ( 0.00053128533%) - largest zero change 1.1896566e-05
# 0  Obj 0 Primal inf 3.5639336 (2)
# 8  Obj 0.33912454
# Optimal - objective value 0.33911205
# Optimal objective 0.3391120505 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/43a73b1d1b494e30818765261d88fa7f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/43a73b1d1b494e30818765261d88fa7f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 5  Obj 1.0000162
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d04ed72084e944608620b0cd1175ada4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d04ed72084e944608620b0cd1175ada4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 5  Obj 0.25649988
# Optimal - objective value 0.25649037
# Optimal objective 0.2564903743 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/62b4c206c132465b97679e3b76b1b2aa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/62b4c206c132465b97679e3b76b1b2aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 12.237064 - largest nonzero change 1.0185854e-05 ( 8.3237722e-05%) - largest zero change 1.0133002e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 6  Obj 0.020388918
# Optimal - objective value 0.02038887
# Optimal objective 0.02038887034 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/64225c66bd374f8d9de0c914da6bcd3c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/64225c66bd374f8d9de0c914da6bcd3c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 12.237064 - largest nonzero change 1.0185854e-05 ( 8.3237722e-05%) - largest zero change 1.0133002e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 6  Obj 0.018957486
# Optimal - objective value 0.01895744
# Optimal objective 0.01895743983 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/412a5016f4bf4facbab3bcc91eccfd1f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/412a5016f4bf4facbab3bcc91eccfd1f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 0.093189587 (2)
# 7  Obj 0.053414995
# Optimal - objective value 0.053413897
# Optimal objective 0.05341389716 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bdf1c81cf8024b1d991dfe1317721136-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bdf1c81cf8024b1d991dfe1317721136-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 25.302864 - largest nonzero change 2.0309446e-05 ( 8.0265406e-05%) - largest zero change 1.6869701e-05
# 0  Obj 0 Primal inf 0.073745763 (2)
# 7  Obj 0.06900851
# Optimal - objective value 0.069008372
# Optimal objective 0.06900837213 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5da907e80a7b42b2bea94ed2c1eb5954-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5da907e80a7b42b2bea94ed2c1eb5954-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 27.87776 - largest nonzero change 2.2304518e-05 ( 8.0008284e-05%) - largest zero change 1.8100132e-05
# 0  Obj 0 Primal inf 0.35428912 (2)
# 8  Obj 0.21398782
# Optimal - objective value 0.21398721
# Optimal objective 0.2139872074 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/766c771c35b14d85be487b61c429e747-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/766c771c35b14d85be487b61c429e747-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 92.006947 - largest nonzero change 7.1992848e-05 ( 7.8247188e-05%) - largest zero change 4.8744678e-05
# 0  Obj 0 Primal inf 0.36779419 (2)
# 8  Obj 0.9286121
# Optimal - objective value 0.92861011
# Optimal objective 0.9286101123 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2a8b9e9ee2684e25859058f5b7cb88dc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2a8b9e9ee2684e25859058f5b7cb88dc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 51.94707 - largest nonzero change 4.0953808e-05 ( 7.8837571e-05%) - largest zero change 2.9601807e-05
# 0  Obj 0 Primal inf 0.28946828 (2)
# 8  Obj 0.70108865
# Optimal - objective value 0.70108749
# Optimal objective 0.7010874869 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cb382870cc9b4ad28e3712b37b22392f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cb382870cc9b4ad28e3712b37b22392f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 42.827984 - largest nonzero change 3.3888193e-05 ( 7.9126285e-05%) - largest zero change 2.5244193e-05
# 0  Obj 0 Primal inf 0.15566439 (2)
# 8  Obj 0.19938222
# Optimal - objective value 0.1993818
# Optimal objective 0.1993817992 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d2a85c4fa8c046e4a9942a489805fbe3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d2a85c4fa8c046e4a9942a489805fbe3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 20.374446 - largest nonzero change 1.6490828e-05 ( 8.0938782e-05%) - largest zero change 1.4514625e-05
# 0  Obj 0 Primal inf 0.48737441 (2)
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 49.628544 - largest nonzero change 3.9157376e-05 ( 7.8900918e-05%) - largest zero change 2.8493884e-05
# 0  Obj 0 Primal inf 1.2689035 (2)
# 4  Obj 0.98552544
# Optimal - objective value 0.98552268
# Optimal objective 0.9855226807 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/873d1ce936bd4c118cfb6e114a2dc979-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/873d1ce936bd4c118cfb6e114a2dc979-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 49.628544 - largest nonzero change 3.9157376e-05 ( 7.8900918e-05%) - largest zero change 2.8493884e-05
# 0  Obj 0 Primal inf 1.2476634 (2)
# 4  Obj 1.0000028
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1d4a21473d0a41febe4ae5776d03f296-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1d4a21473d0a41febe4ae5776d03f296-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 49.628544 - largest nonzero change 3.9157376e-05 ( 7.8900918e-05%) - largest zero change 2.8493884e-05
# 0  Obj 0 Primal inf 1.2788213 (2)
# 6  Obj 0.97785769
# Optimal - objective value 0.97785496
# Optimal objective 0.9778549632 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/54a363e4714040919a3d4796a20e0fe4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/54a363e4714040919a3d4796a20e0fe4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 73.348496 - largest nonzero change 5.7535979e-05 ( 7.8441934e-05%) - largest zero change 3.9828617e-05
# 0  Obj 0 Primal inf 0.61343819 (2)
# 7  Obj 1.0000025
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/732e44cbcc124996b7b5a8da263d7dbd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/732e44cbcc124996b7b5a8da263d7dbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 19.693668 - largest nonzero change 1.5963351e-05 ( 8.1058291e-05%) - largest zero change 1.4189311e-05
# 0  Obj 0 Primal inf 0.040609943 (2)
# 7  Obj 0.031798126
# Optimal - objective value 0.031798063
# Optimal objective 0.03179806339 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1cb0e81aee9a497985a360a6318fc48e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1cb0e81aee9a497985a360a6318fc48e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 46.025102 - largest nonzero change 3.6365372e-05 ( 7.9012039e-05%) - largest zero change 2.6771957e-05
# 0  Obj 0 Primal inf 0.25665356 (2)
# 8  Obj 0.38751533
# Optimal - objective value 0.38751454
# Optimal objective 0.3875145362 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c9e8bb9a43dc4ff795fce0d202cf6f6e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c9e8bb9a43dc4ff795fce0d202cf6f6e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 52.78905 - largest nonzero change 4.1606187e-05 ( 7.8815943e-05%) - largest zero change 3.0004152e-05
# 0  Obj 0 Primal inf 0.27551933 (2)
# 7  Obj 1.0000013
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/92f744a0f1cb4d24a48b73bc6efff329-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/92f744a0f1cb4d24a48b73bc6efff329-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 25.268657 - largest nonzero change 2.0282942e-05 ( 8.0269174e-05%) - largest zero change 1.6853355e-05
# 0  Obj 0 Primal inf 0.11412926 (2)
# 9  Obj 0.16183393
# Optimal - objective value 0.16183367
# Optimal objective 0.1618336749 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1a63c24d76d3446c905816d7f4034068-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1a63c24d76d3446c905816d7f4034068-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 24.144991 - largest nonzero change 1.9412308e-05 ( 8.0398902e-05%) - largest zero change 1.6316404e-05
# 0  Obj 0 Primal inf 0.13556009 (2)
# 5  Obj 0.070696608
# Optimal - objective value 0.070696402
# Optimal objective 0.07069640181 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/feafb2ef9acc478388eef119aa6a292f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/feafb2ef9acc478388eef119aa6a292f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 17.057668 - largest nonzero change 1.3920936e-05 ( 8.1611011e-05%) - largest zero change 1.2929681e-05
# 0  Obj 0 Primal inf 0.04390005 (2)
# 8  Obj 0.03325979
# Optimal - objective value 0.033259728
# Optimal objective 0.03325972757 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5dbe7889ab8c42fcac08ddbb77ae63fa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5dbe7889ab8c42fcac08ddbb77ae63fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 46.619966 - largest nonzero change 3.6826282e-05 ( 7.8992511e-05%) - largest zero change 2.7056216e-05
# 0  Obj 0 Primal inf 0.14809216 (2)
# 8  Obj 0.45496271
# Optimal - objective value 0.45496207
# Optimal objective 0.4549620705 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3818f6484a4a4c959d83db5af57264ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3818f6484a4a4c959d83db5af57264ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 29.846106 - largest nonzero change 2.3829624e-05 ( 7.9841651e-05%) - largest zero change 1.9040719e-05
# 0  Obj 0 Primal inf 0.617327 (2)
# 7  Obj 0.40012352
# Optimal - objective value 0.40012238
# Optimal objective 0.4001223775 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de67f7281c154f3dae2b74f76e416d1a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de67f7281c154f3dae2b74f76e416d1a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.408721 - largest nonzero change 3.4338157e-05 ( 7.9104282e-05%) - largest zero change 2.5521702e-05
# 0  Obj 0 Primal inf 0.18042516 (2)
# 8  Obj 0.16850186
# Optimal - objective value 0.16850141
# Optimal objective 0.1685014126 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/da40d545cf8348b29d4b36570e7fd241-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/da40d545cf8348b29d4b36570e7fd241-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 34.448107 - largest nonzero change 2.7395329e-05 ( 7.9526369e-05%) - largest zero change 2.1239815e-05
# 0  Obj 0 Primal inf 0.28193749 (2)
# 8  Obj 0.21342545
# Optimal - objective value 0.21342487
# Optimal objective 0.213424867 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
df_2022[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency','Overall_Efficiency']]
# Out:
#                                          Hub Airport               Airline  \
# 0               Chicago Midway International Airport    SouthWest Airlines
# 1   Hartsfield-Jackson Atlanta International Airport    SouthWest Airlines
# 2                       Denver International Airport     Frontier Airlines
# 3              Dallas/Ft Worth International Airport     Frontier Airlines
# 4       Minneapolis-Saint Paul International Airport  Sun Country Airlines
# 5                                    Abudabi Airport            Air Arabia
# 6              John F. Kennedy International Airport       JetBlue Airways
# 7                            Ankara Esenboga Airport           Anadolu Jet
# 8                            Ankara Esenboga Airport      Pegasus Airlines
# 9                                 Dusseldorf Airport             Eurowings
# 10               Indira Gandhi International Airport                IndiGo
# 11               Indira Gandhi International Airport              SpiceJet
# 12                                    Geneva Airport               EasyJet
# 13                                    Dublin Airport               Ryanair
# 14                     Incheon International Airport             Air Seoul
# 15                     Incheon International Airport             Air Busan
# 16                     Incheon International Airport               Jin Air
# 17                     Incheon International Airport              Jeju Air
# 18                     Incheon International Airport        T'way Airlines
# 19                      Narita International Airport         Jetstar Japan
# 20                                    Changi Airport                 Scoot
# 21       Budapest Ferenc Liszt International Airport              Wizz Air
# 22                    HongKong International Airport            HK Express
# 23             Toronto Pearson International Airport               WestJet
# 24        Aeropuerto de Adolfo Suárez Madrid-Barajas            Air Europa
# 25                              Suvarnabhumi Airport          Thai AirAsia
# 26                                 Melbourne Airport     Jetstar Australia
# 27   Fort Lauderdale-Hollywood International Airport        Spirit Airline
# 28                            Aéroport de Paris-Orly      Transavia France
# 29            The Ninoy Aquino International Airport      Cebu Pacific Air
#
#     Airport_Efficiency  Airline_Efficiency  Overall_Efficiency
# 0             1.000000            1.000000            1.000000
# 1             0.574333            0.256490            0.147311
# 2             0.696795            0.020389            0.014207
# 3             0.344595            0.018957            0.006533
# 4             0.296529            0.053414            0.015839
# 5             0.366179            0.069008            0.025269
# 6             0.070238            0.213987            0.015030
# 7             0.179593            0.928610            0.166772
# 8             0.240897            0.701087            0.168890
# 9             0.159516            0.199382            0.031804
# 10            0.146488            0.216195            0.031670
# 11            0.146488            0.115023            0.016850
# 12            1.000000            0.313990            0.313990
# 13            1.000000            0.762506            0.762506
# 14            0.087258            1.000000            0.087258
# 15            0.087258            1.000000            0.087258
# 16            0.087258            0.985523            0.085995
# 17            0.087258            1.000000            0.087258
# 18            0.087258            0.977855            0.085326
# 19            0.089762            1.000000            0.089762
# 20            0.384532            0.031798            0.012227
# 21            0.333120            0.387515            0.129089
# 22            0.108724            1.000000            0.108724
# 23            0.319412            0.161834            0.051692
# 24            0.123612            0.070696            0.008739
# 25            0.353099            0.033260            0.011744
# 26            0.196550            0.454962            0.089423
# 27            1.000000            0.400122            0.400122
# 28            0.094060            0.168501            0.015849
# 29            0.339112            0.213425            0.072375

# %%
# Define a function to calculate the Malmquist index
def malmquist_index(inputs_t1, outputs_t1, inputs_t2, outputs_t2):
    # Calculate efficiency scores inside each stage
    eff_t1 = calculate_efficiency(inputs_t1, outputs_t1)
    eff_t2 = calculate_efficiency(inputs_t2, outputs_t2)

    # Calculate efficiency scores between stages
    eff_t1_t2 = calculate_efficiency(inputs_t1, outputs_t2)
    eff_t2_t1 = calculate_efficiency(inputs_t2, outputs_t1)

    # Calculate efficiency change and technology change
    EC = eff_t2 / eff_t1
    TC = np.sqrt((eff_t1_t2 / eff_t2) * (eff_t1 / eff_t2_t1))
    # Calulate Malmquist index
    MI = EC * TC
    return MI, EC, TC

# %%
# Generate the inputs
inputs_2022_1 = df_2022[['operating_expense', 'Terminal_Size']]
inputs_2023_1 = df_2023[['operating_expense', 'Terminal_Size']]
outputs_2022_1 = df_2022[['Total_Aircraft_Movements','Total_Passenger_Traffic']]
outputs_2023_1 = df_2023[['Total_Aircraft_Movements','Total_Passenger_Traffic']]
inputs_2022_2 = df_2022[['Total_Aircraft_Movements','Total_Passenger_Traffic','Operation_Cost']]
inputs_2023_2 = df_2023[['Total_Aircraft_Movements','Total_Passenger_Traffic','Operation_Cost']]
outputs_2022_2 = df_2022[['Airline_CPE', 'On_Time_Performance_Rate']]
outputs_2023_2 = df_2023[['Airline_CPE', 'On_Time_Performance_Rate']]

# Convert the dataframes to numpy arrays
inputs_2022_1 = inputs_2022_1.to_numpy()
inputs_2023_1 = inputs_2023_1.to_numpy()
inputs_2022_2 = inputs_2022_2.to_numpy()
inputs_2023_2 = inputs_2023_2.to_numpy()
outputs_2022_1 = outputs_2022_1.to_numpy()
outputs_2023_1 = outputs_2023_1.to_numpy()
outputs_2022_2 = outputs_2022_2.to_numpy()
outputs_2023_2 = outputs_2023_2.to_numpy()


# Calculate the Malmquist index
MI_Stage1, EC_Stage1, TC_Stage1 = malmquist_index(inputs_2022_1, outputs_2022_1, inputs_2023_1, outputs_2023_1)

print("Malmquist Index (MI):", MI_Stage1)
print("Efficiency Change (EC):", EC_Stage1)
print("Technological Change (TC):", TC_Stage1)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a2f4ccccd88b45ccbd3fcb867fd58a6a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a2f4ccccd88b45ccbd3fcb867fd58a6a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3049976 (2)
# 4  Obj 0.62608969
# Optimal - objective value 0.62608969
# After Postsolve, objective 0.62608969, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.6260896853 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cde4f734ae244ac3a9ebeae3f2dd495f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cde4f734ae244ac3a9ebeae3f2dd495f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.1037953 (2)
# 3  Obj 0.58579801
# Optimal - objective value 0.58579801
# After Postsolve, objective 0.58579801, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5857980147 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/33a1ff6fe1de4c2e8854fb36f4dfa310-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/33a1ff6fe1de4c2e8854fb36f4dfa310-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 3.717479 (2)
# 2  Obj 0.69679549
# Optimal - objective value 0.69679549
# After Postsolve, objective 0.69679549, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.6967954865 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/badca739a49545f8a5cb21b4e0164fc9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/badca739a49545f8a5cb21b4e0164fc9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.1306757 (2)
# 2  Obj 0.34459536
# Optimal - objective value 0.34459536
# After Postsolve, objective 0.34459536, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3445953585 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6b25348d64364c11b84954b35f9afaff-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6b25348d64364c11b84954b35f9afaff-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.5515137 (2)
# 3  Obj 0.41354567
# Optimal - objective value 0.41354567
# After Postsolve, objective 0.41354567, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4135456706 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ad9999f9ef4f45b7b3093e8b4041a0df-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ad9999f9ef4f45b7b3093e8b4041a0df-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.6227199 (2)
# 4  Obj 0.41409096
# Optimal - objective value 0.41409096
# After Postsolve, objective 0.41409096, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4140909591 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/24c90055c11644dd85bd089f201a8808-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/24c90055c11644dd85bd089f201a8808-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 3.0005301 (2)
# 4  Obj 0.1131509
# Optimal - objective value 0.1131509
# After Postsolve, objective 0.1131509, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1131508998 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/59fa0a77fccb49719a04467d7d0823c2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/59fa0a77fccb49719a04467d7d0823c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.58764526 (2)
# 4  Obj 0.26451387
# Optimal - objective value 0.26451387
# After Postsolve, objective 0.26451387, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2645138662 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ecebb0e63378475a824fed28a2e74df5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ecebb0e63378475a824fed28a2e74df5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.58764526 (2)
# 4  Obj 0.26451387
# Optimal - objective value 0.26451387
# After Postsolve, objective 0.26451387, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2645138662 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a89a1a22e9ab46019c351a4616a1ca5e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a89a1a22e9ab46019c351a4616a1ca5e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.1923748 (2)
# 5  Obj 0.24002082
# Optimal - objective value 0.24002082
# After Postsolve, objective 0.24002082, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2400208174 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a6c008a5dbf643a5b72a816af78cd947-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a6c008a5dbf643a5b72a816af78cd947-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-2) rows, 24 (-7) columns and 48 (-74) elements
# 0  Obj 0 Primal inf 1.5749634 (2)
# 1  Obj 0.40886542
# Optimal - objective value 0.40886542
# After Postsolve, objective 0.40886542, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4088654224 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8f118ce54d2c4858a089dc5db2d76a0f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8f118ce54d2c4858a089dc5db2d76a0f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-2) rows, 24 (-7) columns and 48 (-74) elements
# 0  Obj 0 Primal inf 1.5749634 (2)
# 1  Obj 0.40886542
# Optimal - objective value 0.40886542
# After Postsolve, objective 0.40886542, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4088654224 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/17b01aa9c7a74d4785de9afa9468fca3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/17b01aa9c7a74d4785de9afa9468fca3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-4) rows, 0 (-31) columns and 0 (-122) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/23a4e7d3f442487ab59caab4f2fdfc53-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/23a4e7d3f442487ab59caab4f2fdfc53-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.70614546 (2)
# 3  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/31be5a0211f94c70a83edcc52855426b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/31be5a0211f94c70a83edcc52855426b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/edef04986b0b4eef89cf2b6167c6c9de-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/edef04986b0b4eef89cf2b6167c6c9de-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8b91006de78146b4bd317de360c3c28f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8b91006de78146b4bd317de360c3c28f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1eef88ba57144beeb19de9b6bdadb998-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1eef88ba57144beeb19de9b6bdadb998-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c8585d02b7d4831ab9166d61ebad3b0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c8585d02b7d4831ab9166d61ebad3b0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/95cb5d6122ed4add9c2eb4f0f6bf4d67-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/95cb5d6122ed4add9c2eb4f0f6bf4d67-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 72 (-50) elements
# 0  Obj 0 Primal inf 1.1680974 (2)
# 3  Obj 0.23086036
# Optimal - objective value 0.23086036
# After Postsolve, objective 0.23086036, infeasibilities - dual 0.36513353 (3), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 0.23086036 Dual inf 0.28360803 (3)
# 4  Obj 0.16055146
# Optimal - objective value 0.16055146
# Optimal objective 0.1605514609 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6ba07f1d4c8f45c997d7ee050b6e0077-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6ba07f1d4c8f45c997d7ee050b6e0077-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.2388755 (2)
# 1  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/39b11b1971ad48c7b069b5596210ed97-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/39b11b1971ad48c7b069b5596210ed97-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.0570762 (2)
# 3  Obj 0.4345698
# Optimal - objective value 0.4345698
# After Postsolve, objective 0.4345698, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4345698024 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f51ab9cba28f41f0b47c2b7c6a5c1f92-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f51ab9cba28f41f0b47c2b7c6a5c1f92-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.2241094 (2)
# 3  Obj 0.13255423
# Optimal - objective value 0.13255423
# After Postsolve, objective 0.13255423, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1325542291 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f8d3e7f5ec0343c19581232e8c4532a6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f8d3e7f5ec0343c19581232e8c4532a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.2672313 (2)
# 4  Obj 0.47253023
# Optimal - objective value 0.47253023
# After Postsolve, objective 0.47253023, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4725302326 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f9f6d516c26c4683b1b6673a18131696-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f9f6d516c26c4683b1b6673a18131696-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.7249645 (2)
# 2  Obj 0.32691392
# Optimal - objective value 0.32691392
# After Postsolve, objective 0.32691392, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.326913918 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3f49b033b72046bfb9aff16fc0d310a6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3f49b033b72046bfb9aff16fc0d310a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.7514044 (2)
# 4  Obj 0.62193244
# Optimal - objective value 0.62193244
# After Postsolve, objective 0.62193244, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.6219324415 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/80eeaef3359548e199c6644411047d5d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/80eeaef3359548e199c6644411047d5d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 72 (-50) elements
# 0  Obj 0 Primal inf 1.424238 (2)
# 2  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0.99045599 (2), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1 Dual inf 0.70611094 (2)
# 1  Obj 0.94500777
# Optimal - objective value 0.94500777
# Optimal objective 0.9450077713 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/698f2b87b8da4b2db7091beaf7f102c2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/698f2b87b8da4b2db7091beaf7f102c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.2459256 (2)
# 1  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1fd29883cd274746882c9a275981888b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1fd29883cd274746882c9a275981888b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.1631671 (2)
# 5  Obj 0.18893055
# Optimal - objective value 0.18893055
# After Postsolve, objective 0.18893055, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1889305533 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3d5de0c50e704cf19cc5b48dc25191af-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3d5de0c50e704cf19cc5b48dc25191af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.8104068 (2)
# 5  Obj 0.54932843
# Optimal - objective value 0.54932843
# After Postsolve, objective 0.54932843, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5493284321 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/25d76e4bc8524c009b176f7a0c46d9bd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/25d76e4bc8524c009b176f7a0c46d9bd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.7724352 (2)
# 4  Obj 0.5100765
# Optimal - objective value 0.5100765
# After Postsolve, objective 0.5100765, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5100764982 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e4e7595020224c6e9480fcbb01bff204-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e4e7595020224c6e9480fcbb01bff204-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 5.7680825 (2)
# 4  Obj 0.67930393
# Optimal - objective value 0.67930393
# After Postsolve, objective 0.67930393, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.679303932 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8e6f3b8fd5ac40278c580eb7c0c2cb57-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8e6f3b8fd5ac40278c580eb7c0c2cb57-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.5832375 (2)
# 4  Obj 0.90118036
# Optimal - objective value 0.90118036
# After Postsolve, objective 0.90118036, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.9011803615 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/93479bc431394603a76b2c010a202b36-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/93479bc431394603a76b2c010a202b36-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 5.0720532 (2)
# 3  Obj 0.38167765
# Optimal - objective value 0.38167765
# After Postsolve, objective 0.38167765, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3816776525 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3802435999c4473696af8e98da0b2e8a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3802435999c4473696af8e98da0b2e8a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.90530174 (2)
# 4  Obj 0.3944011
# Optimal - objective value 0.3944011
# After Postsolve, objective 0.3944011, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3944011007 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/58590ee432dc486782b4f910e451ff31-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/58590ee432dc486782b4f910e451ff31-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 3.9111817 (2)
# 3  Obj 0.7081506
# Optimal - objective value 0.7081506
# After Postsolve, objective 0.7081506, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.7081505982 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f651b7d9d2b14e84bf8b1fd8a0fbc255-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f651b7d9d2b14e84bf8b1fd8a0fbc255-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3525575 (2)
# 3  Obj 0.16947017
# Optimal - objective value 0.16947017
# After Postsolve, objective 0.16947017, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1694701693 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d725f712fb6144198974aa6086399b75-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d725f712fb6144198974aa6086399b75-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.99126312 (2)
# 4  Obj 0.27586212
# Optimal - objective value 0.27586212
# After Postsolve, objective 0.27586212, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2758621204 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de6eab1ba5634a03a56744ff620c381d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de6eab1ba5634a03a56744ff620c381d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.99126312 (2)
# 4  Obj 0.27586212
# Optimal - objective value 0.27586212
# After Postsolve, objective 0.27586212, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2758621204 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/868af2b05a5146ea899c1e09cb86e901-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/868af2b05a5146ea899c1e09cb86e901-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.46206499 (2)
# 3  Obj 0.22390942
# Optimal - objective value 0.22390942
# After Postsolve, objective 0.22390942, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2239094222 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e9840a0a98db45e9821796cadf28772e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e9840a0a98db45e9821796cadf28772e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5740832 (2)
# 2  Obj 0.32165954
# Optimal - objective value 0.32165954
# After Postsolve, objective 0.32165954, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3216595437 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ddec4e5cc4814de7b03d3b2a70ca0e4f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ddec4e5cc4814de7b03d3b2a70ca0e4f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5740832 (2)
# 2  Obj 0.32165954
# Optimal - objective value 0.32165954
# After Postsolve, objective 0.32165954, infeasibilities - dual 0 (0), primal 0 (0)
# ...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a37af13d75864a8fb0fbab2107b09aa2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a37af13d75864a8fb0fbab2107b09aa2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3008908 (2)
# 4  Obj 0.12629552
# Optimal - objective value 0.12629552
# After Postsolve, objective 0.12629552, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1262955165 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a3b545c2b6e943fb9d2d200a3aee7b20-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a3b545c2b6e943fb9d2d200a3aee7b20-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3008908 (2)
# 4  Obj 0.12629552
# Optimal - objective value 0.12629552
# After Postsolve, objective 0.12629552, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1262955165 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/72f94e86b8ed49db8716b1e51def8817-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/72f94e86b8ed49db8716b1e51def8817-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.90969707 (2)
# 5  Obj 0.10745086
# Optimal - objective value 0.10745086
# After Postsolve, objective 0.10745086, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1074508593 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1ab4f1bd0bf648808780ed7f7cdef760-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1ab4f1bd0bf648808780ed7f7cdef760-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 25 (-6) columns and 98 (-24) elements
# Perturbing problem by 0.001% of 0.39528985 - largest nonzero change 3.999674e-05 ( 0.010118332%) - largest zero change 3.994787e-05
# 0  Obj 0 Primal inf 2.528675 (2)
# 8  Obj 1.0001597
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/543d20d4e8824ce4a2921c3ac8c545e9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/543d20d4e8824ce4a2921c3ac8c545e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.0351621 (2)
# 3  Obj 0.36674562
# Optimal - objective value 0.36674562
# After Postsolve, objective 0.36674562, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3667456224 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d7544717ee154153ab847ba13f22cf1a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d7544717ee154153ab847ba13f22cf1a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.0090286 (2)
# 3  Obj 0.13250237
# Optimal - objective value 0.13250237
# After Postsolve, objective 0.13250237, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1325023733 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e47df0d32c9749b5a96ab9b3c378f56f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e47df0d32c9749b5a96ab9b3c378f56f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.5117002 (2)
# 4  Obj 0.35495081
# Optimal - objective value 0.35495081
# After Postsolve, objective 0.35495081, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3549508121 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/103d6619a9d6484789ab1c54c377c434-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/103d6619a9d6484789ab1c54c377c434-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.7323956 (2)
# 3  Obj 0.33351534
# Optimal - objective value 0.33351534
# After Postsolve, objective 0.33351534, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.333515337 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6c68b0f9fd48400e934af6e03608fb14-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6c68b0f9fd48400e934af6e03608fb14-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.129983 (2)
# 5  Obj 0.58515378
# Optimal - objective value 0.58515378
# After Postsolve, objective 0.58515378, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5851537809 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/78ae8c381f93463d9379d33fee885255-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/78ae8c381f93463d9379d33fee885255-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.296018 (2)
# 3  Obj 0.75752825
# Optimal - objective value 0.75752825
# After Postsolve, objective 0.75752825, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.7575282528 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/998f990053224cc5b1893ba91a7386ac-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/998f990053224cc5b1893ba91a7386ac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.4136542 (2)
# 1  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fb3f2e2238bc48019b5ce6de869e290c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fb3f2e2238bc48019b5ce6de869e290c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.1754333 (2)
# 4  Obj 0.16962423
# Optimal - objective value 0.16962423
# After Postsolve, objective 0.16962423, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1696242312 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9f9e2f235a064ba7977995d6251f4d47-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9f9e2f235a064ba7977995d6251f4d47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.8104068 (2)
# 5  Obj 0.50206271
# Optimal - objective value 0.50206271
# After Postsolve, objective 0.50206271, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5020627091 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Malmquist Index (MI): [0.97708169 1.16529979 1.24393088 1.09127045 0.99288712 1.72079127
#  1.50476186 1.18249158 1.18249158 1.02512433 0.69287772 0.69287772
#  1.         1.         2.59384353 2.59384353 2.59384353 2.59384353
#  2.59384353 1.85773261 1.         1.13488173 2.67202132 1.07835464
#  0.90689543 1.57754284 1.05105871 1.         0.97046752 1.27392876]
# Efficiency Change (EC): [0.81470196 1.15962144 1.29332117 1.10761111 0.95370627 1.71013296
#  1.49773594 1.04290229 1.04290229 0.93287499 0.78671251 0.78671251
#  1.         1.         2.52315611 2.52315611 2.52315611 2.52315611
#  2.52315611 1.24229297 1.         0.95588978 2.58101827 0.80320032
#  1.00022039 1.48077119 0.84063615 1.         0.87168978 1.16513221]
# Technological Change (TC): [1.19931182 1.00489673 0.96181127 0.98524694 1.04108272 1.00623244
#  1.00469102 1.13384695 1.13384695 1.09888714 0.88072544 0.88072544
#  1.         1.         1.02801548 1.02801548 1.02801548 1.02801548
#  1.02801548 1.4954062  1.         1.18725166 1.03525858 1.34257248
#  0.9066956  1.0653522  1.25031349 1.         1.11331754 1.093377  ]

# %%
MI_Stage2, EC_Stage2, TC_Stage2 = malmquist_index(inputs_2022_2, outputs_2022_2, inputs_2023_2, outputs_2023_2)

print("Malmquist Index (MI):", MI_Stage2)
print("Efficiency Change (EC):", EC_Stage2)
print("Technological Change (TC):", TC_Stage2)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b703a3eb05624c96a8e97f0f77f17cd4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b703a3eb05624c96a8e97f0f77f17cd4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 38.718421 - largest nonzero change 3.0704037e-05 ( 7.930085e-05%) - largest zero change 2.3280412e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 7  Obj 1.0000026
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/38e679ead55d4c6db3d40a2f43b2842a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/38e679ead55d4c6db3d40a2f43b2842a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 7  Obj 0.51096647
# Optimal - objective value 0.51095467
# Optimal objective 0.5109546708 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/17ab5d9201cb45648a9aa72fa1feef0f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/17ab5d9201cb45648a9aa72fa1feef0f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 12.237064 - largest nonzero change 1.0185854e-05 ( 8.3237722e-05%) - largest zero change 1.0133002e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 6  Obj 0.037853704
# Optimal - objective value 0.037853639
# Optimal objective 0.03785363949 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cadb5cb9dea546f09c6f3a97d576c895-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cadb5cb9dea546f09c6f3a97d576c895-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 12.237064 - largest nonzero change 1.0185854e-05 ( 8.3237722e-05%) - largest zero change 1.0133002e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 6  Obj 0.040349717
# Optimal - objective value 0.04034965
# Optimal objective 0.04034965025 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8f663086e2484a02a8b3a8fd523511f0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8f663086e2484a02a8b3a8fd523511f0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 0.093189587 (2)
# 9  Obj 0.056420989
# Optimal - objective value 0.056419821
# Optimal objective 0.05641982144 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a64431338a9246dd8a9b7552f4192dd6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a64431338a9246dd8a9b7552f4192dd6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 25.302864 - largest nonzero change 2.0309446e-05 ( 8.0265406e-05%) - largest zero change 1.6869701e-05
# 0  Obj 0 Primal inf 0.073745763 (2)
# 8  Obj 0.11053294
# Optimal - objective value 0.11053277
# Optimal objective 0.1105327668 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/52058448c1d14875849bc4ae5a9c8cd3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/52058448c1d14875849bc4ae5a9c8cd3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 23.674264 - largest nonzero change 1.9047581e-05 ( 8.0456908e-05%) - largest zero change 1.6091465e-05
# 0  Obj 0 Primal inf 0.35428912 (2)
# 7  Obj 0.23826101
# Optimal - objective value 0.23826041
# Optimal objective 0.2382604085 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b7ffab906b3e440e9572e9dd6da8dfc8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b7ffab906b3e440e9572e9dd6da8dfc8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 88.84528 - largest nonzero change 6.9543138e-05 ( 7.8274431e-05%) - largest zero change 4.7233855e-05
# 0  Obj 0 Primal inf 0.36779419 (2)
# 8  Obj 0.87136038
# Optimal - objective value 0.87135841
# Optimal objective 0.8713584115 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4f4aa6562e6f48a3a01d9f8d705b2a66-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4f4aa6562e6f48a3a01d9f8d705b2a66-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 51.94707 - largest nonzero change 4.0953808e-05 ( 7.8837571e-05%) - largest zero change 2.9601807e-05
# 0  Obj 0 Primal inf 0.28946828 (2)
# 9  Obj 0.65240424
# Optimal - objective value 0.65240309
# Optimal objective 0.6524030872 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b38af4236f7d4d86bebf13257144f054-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b38af4236f7d4d86bebf13257144f054-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 42.827984 - largest nonzero change 3.3888193e-05 ( 7.9126285e-05%) - largest zero change 2.5244193e-05
# 0  Obj 0 Primal inf 0.15566439 (2)
# 9  Obj 0.18537711
# Optimal - objective value 0.18537668
# Optimal objective 0.1853766775 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e1b6f34cf0ca4839a3583a0eaa16ae25-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e1b6f34cf0ca4839a3583a0eaa16ae25-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 0.48737441 (2)
# 9  Obj 0.21076087
# Optimal - objective value 0.21075555
# Optimal objective 0.2107555468 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/99541f8c759d46ff810784a2f9c4e225-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/99541f8c759d46ff810784a2f9c4e225-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 0.19095358 (2)
# 9  Obj 0.083853852
# Optimal - objective value 0.083851793
# Optimal objective 0.08385179305 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/82188913f4594bcf8bafaa3ffe98d8e3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/82188913f4594bcf8bafaa3ffe98d8e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 20.77514 - largest nonzero change 1.6801293e-05 ( 8.0872103e-05%) - largest zero change 1.4706099e-05
# 0  Obj 0 Primal inf 0.29833923 (2)
# 8  Obj 0.41511449
# Optimal - objective value 0.41511382
# Optimal objective 0.4151138235 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d257994095d34108ae319766bcfad38a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d257994095d34108ae319766bcfad38a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 19.367854 - largest nonzero change 1.5710905e-05 ( 8.1118459e-05%) - largest zero change 1.4033618e-05
# 0  Obj 0 Primal inf 1.2641568 (2)
# 7  Obj 0.76250705
# Optimal - objective value 0.76250552
# Optimal objective 0.7625055241 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cdbf15ce6bee4ef39cbe56ecce7790be-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cdbf15ce6bee4ef39cbe56ecce7790be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2427352 (2)
# 6  Obj 1.0000021
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d76fe222c9e44b36b393a3745878be37-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d76fe222c9e44b36b393a3745878be37-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.4159371 (2)
# 4  Obj 1.0000026
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f87e578d1a4843b59199027b61e59ca7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f87e578d1a4843b59199027b61e59ca7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2689035 (2)
# 5  Obj 0.98552523
# Optimal - objective value 0.98552268
# Optimal objective 0.9855226807 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/36926391687246b8836b322ef51f784a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/36926391687246b8836b322ef51f784a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2476634 (2)
# 4  Obj 1.0000026
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c8737b377c474db7848878aeae67b56e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c8737b377c474db7848878aeae67b56e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2788213 (2)
# 5  Obj 0.9754957
# Optimal - objective value 0.97549319
# Optimal objective 0.9754931901 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b55108fd40dd42a69a5e1f3176671770-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b55108fd40dd42a69a5e1f3176671770-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 50.022364 - largest nonzero change 3.9462515e-05 ( 7.8889744e-05%) - largest zero change 2.8682074e-05
# 0  Obj 0 Primal inf 0.61343819 (2)
# 7  Obj 1.000002
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/85e3170acf794c2aa96bfaa8ebdbba80-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/85e3170acf794c2aa96bfaa8ebdbba80-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 19.693668 - largest nonzero change 1.5963351e-05 ( 8.1058291e-05%) - largest zero change 1.4189311e-05
# 0  Obj 0 Primal inf 0.040609943 (2)
# 7  Obj 0.027707243
# Optimal - objective value 0.027707181
# Optimal objective 0.02770718144 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de65d8a016bc4e2ab65f16ea8e42b071-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de65d8a016bc4e2ab65f16ea8e42b071-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 46.025102 - largest nonzero change 3.6365372e-05 ( 7.9012039e-05%) - largest zero change 2.6771957e-05
# 0  Obj 0 Primal inf 0.25665356 (2)
# 9  Obj 0.41244129
# Optimal - objective value 0.41244046
# Optimal objective 0.4124404563 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f8072f55ea5048398767dd02fd9e9ae0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f8072f55ea5048398767dd02fd9e9ae0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 52.78905 - largest nonzero change 4.1606187e-05 ( 7.8815943e-05%) - largest zero change 3.0004152e-05
# 0  Obj 0 Primal inf 0.27551933 (2)
# 8  Obj 1.0000013
# Optimal - objective value 1
# Optimal objective 1 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bdfe1b5ff0f9456895001e758e37ba64-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bdfe1b5ff0f9456895001e758e37ba64-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 21.661263 - largest nonzero change 1.7487875e-05 ( 8.0733405e-05%) - largest zero change 1.5129539e-05
# 0  Obj 0 Primal inf 0.11412926 (2)
# 7  Obj 0.078236591
# Optimal - objective value 0.078236411
# Optimal objective 0.07823641108 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/09a03663eaba475fae2b4aa1d93f5bb1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/09a03663eaba475fae2b4aa1d93f5bb1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 15.23994 - largest nonzero change 1.251253e-05 ( 8.210354e-05%) - largest zero change 1.2337755e-05
# 0  Obj 0 Primal inf 0.13556009 (2)
# 5  Obj 0.066330597
# Optimal - objective value 0.066330413
# Optimal objective 0.06633041327 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d71dadceacee4ae8ba7618412615650e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d71dadceacee4ae8ba7618412615650e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 17.057668 - largest nonzero change 1.3920936e-05 ( 8.1611011e-05%) - largest zero change 1.2929681e-05
# 0  Obj 0 Primal inf 0.04390005 (2)
# 9  Obj 0.029246332
# Optimal - objective value 0.02924627
# Optimal objective 0.02924626987 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/51e754b3b10a4d4f9df40fdea9aed3b0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/51e754b3b10a4d4f9df40fdea9aed3b0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 30.016167 - largest nonzero change 2.396139e-05 ( 7.982828e-05%) - largest zero change 1.9121984e-05
# 0  Obj 0 Primal inf 0.14809216 (2)
# 10  Obj 0.40792771
# Optimal - objective value 0.40792718
# Optimal objective 0.407927177 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0e851ade559841e08871533ea79f2c77-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0e851ade559841e08871533ea79f2c77-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 29.846106 - largest nonzero change 2.3829624e-05 ( 7.9841651e-05%) - largest zero change 1.9040719e-05
# 0  Obj 0 Primal inf 0.617327 (2)
# 8  Obj 0.86081313
# Optimal - objective value 0.86081158
# Optimal objective 0.8608115835 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5210f7c5427e4480b062e4b7f3edb73b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5210f7c5427e4480b062e4b7f3edb73b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 26.420456 - largest nonzero change 2.1175375e-05 ( 8.0147651e-05%) - largest zero change 1.740375e-05
# 0  Obj 0 Primal inf 0.18042516 (2)
# 8  Obj 0.15182439
# Optimal - objective value 0.15182404
# Optimal objective 0.1518240381 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e78716a140014cceb8677bf3c44ddbb2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e78716a140014cceb8677bf3c44ddbb2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 24.906474 - largest nonzero change 2.0002317e-05 ( 8.030971e-05%) - largest zero change 1.6680284e-05
# 0  Obj 0 Primal inf 0.28193749 (2)
# 7  Obj 0.21408143
# Optimal - objective value 0.21408093
# Optimal objective 0.2140809318 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/54c6f8e3eeac44e896f4a6e7ff82cb68-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/54c6f8e3eeac44e896f4a6e7ff82cb68-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.0954487 - largest nonzero change 3.1027821e-05 ( 0.0010023691%) - largest zero change 3.0187112e-05
# 0  Obj 0 Primal inf 2.7378351 (2)
# 7  Obj 1.0000242
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4505bdcce4524ab1971a9e4aad993f94-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4505bdcce4524ab1971a9e4aad993f94-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.8190225 - largest nonzero change 2.1137864e-05 ( 0.0011620452%) - largest zero change 2.1036287e-05
# 0  Obj 0 Primal inf 2.7378351 (2)
# 4  Obj 0.60312278
# Optimal - objective value 0.60310951
# Optimal objective 0.6031095051 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/69770bff6bf44a3dbe9e3c0ee30a14df-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/69770bff6bf44a3dbe9e3c0ee30a14df-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.3237893 - largest nonzero change 2.5048879e-05 ( 0.0010779324%) - largest zero change 2.4774527e-05
# 0  Obj 0 Primal inf 0.52342188 (2)
# 7  Obj 0.098566365
# Optimal - objective value 0.098563048
# Optimal objective 0.09856304808 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e44cf3c96f8a43ffb89f1869758443d4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e44cf3c96f8a43ffb89f1869758443d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.3060188 - largest nonzero change 2.491119e-05 ( 0.0010802683%) - largest zero change 2.4738803e-05
# 0  Obj 0 Primal inf 0.52342188 (2)
# 6  Obj 0.10544785
# Optimal - objective value 0.10544451
# Optimal objective 0.1054445117 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/10bb7b96ae434a32859a03909281d8f5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/10bb7b96ae434a32859a03909281d8f5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.5996168 - largest nonzero change 2.7186035e-05 ( 0.0010457708%) - largest zero change 2.6931903e-05
# 0  Obj 0 Primal inf 0.29747686 (2)
# 8  Obj 0.12057988
# Optimal - objective value 0.12057694
# Optimal objective 0.1205769427 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/949a215060924cfb9aa27edd7ad0c3cf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/949a215060924cfb9aa27edd7ad0c3cf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.0155201 - largest nonzero change 2.2660359e-05 ( 0.0011242934%) - largest zero change 2.1621247e-05
# 0  Obj 0 Primal inf 0.33265579 (2)
# 7  Obj 0.067461974
# Optimal - objective value 0.06746045
# Optimal objective 0.06746045039 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dc6708e1bc7c4090a1c7c77edc5b3232-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dc6708e1bc7c4090a1c7c77edc5b3232-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.5972831 - largest nonzero change 1.9419791e-05 ( 0.0012158014%) - largest zero change 1.9053356e-05
# 0  Obj 0 Primal inf 0.99601372 (2)
# 5  Obj 0.23615211
# Optimal - objective value 0.23614686
# Optimal objective 0.2361468562 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c191a3115da4ba0958b54e4ca567e9a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c191a3115da4ba0958b54e4ca567e9a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 7.5868839 - largest nonzero change 6.5828187e-05 ( 0.00086765775%) - largest zero change 6.3293199e-05
# 0  Obj 0 Primal inf 1.388316 (2)
# 3  Obj 1.0000172
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fe955d6ce1424290b9a3e4eb32a976fa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fe955d6ce1424290b9a3e4eb32a976fa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.073858 - largest nonzero change 3.8608694e-05 ( 0.0009477182%) - largest zero change 3.8549199e-05
# 0  Obj 0 Primal inf 0.79526833 (2)
# 9  Obj 0.48738299
# Optimal - objective value 0.48737403
# Optimal objective 0.4873740281 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/db47406b625545c4bd5c46b5a9221660-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/db47406b625545c4bd5c46b5a9221660-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.3520421 - largest nonzero change 3.3015948e-05 ( 0.00098495026%) - largest zero change 3.1901798e-05
# 0  Obj 0 Primal inf 0.47298363 (2)
# 7  Obj 0.14098424
# Optimal - objective value 0.14098048
# Optimal objective 0.1409804837 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/93e627f6221f428ba36702f8b68266e3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/93e627f6221f428ba36702f8b68266e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.2281353 - largest nonzero change 1.6559574e-05 ( 0.001348351%) - largest zero change 1.5377291e-05
# 0  Obj 0 Primal inf 1.2698509 (2)
# 10  Obj 0.22029041
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.1851052 - largest nonzero change 2.3974332e-05 ( 0.0010971706%) - largest zero change 2.382523e-05
# 0  Obj 0 Primal inf 13.812164 (2)
# 5  Obj 1.0000311
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6ec98179b0de4177856fa3dc3001b57c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6ec98179b0de4177856fa3dc3001b57c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.1851052 - largest nonzero change 2.3974332e-05 ( 0.0010971706%) - largest zero change 2.382523e-05
# 0  Obj 0 Primal inf 13.608704 (2)
# 6  Obj 0.97006734
# Optimal - objective value 0.97003734
# Optimal objective 0.9700373433 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7ee1b80571c54eaaa9c28a1827067e29-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7ee1b80571c54eaaa9c28a1827067e29-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.7505477 - largest nonzero change 3.6103633e-05 ( 0.00096262296%) - largest zero change 3.285394e-05
# 0  Obj 0 Primal inf 2.5645915 (2)
# 4  Obj 1.0000181
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8b391d6f0ef3420592ca4fa2a2614f48-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8b391d6f0ef3420592ca4fa2a2614f48-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.0826043 - largest nonzero change 2.3180138e-05 ( 0.0011130361%) - largest zero change 2.3156357e-05
# 0  Obj 0 Primal inf 0.23093838 (2)
# 7  Obj 0.033197723
# Optimal - objective value 0.033197023
# Optimal objective 0.0331970231 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/36bef0debdea4f198955135fc2997cf6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/36bef0debdea4f198955135fc2997cf6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.4947921 - largest nonzero change 4.187016e-05 ( 0.00093152605%) - largest zero change 3.9702165e-05
# 0  Obj 0 Primal inf 1.0888739 (2)
# 7  Obj 0.35876413
# Optimal - objective value 0.3587567
# Optimal objective 0.3587566954 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a1e5dff62fe340959fc9a3025793b30a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a1e5dff62fe340959fc9a3025793b30a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7138361 - largest nonzero change 2.8071024e-05 ( 0.001034367%) - largest zero change 2.7609785e-05
# 0  Obj 0 Primal inf 1.1951881 (2)
# 5  Obj 0.28389746
# Optimal - objective value 0.28389096
# Optimal objective 0.2838909645 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/aafad8b6b756480cac50f3c531b1e8de-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/aafad8b6b756480cac50f3c531b1e8de-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7380668 - largest nonzero change 2.8258768e-05 ( 0.0010320701%) - largest zero change 2.7662405e-05
# 0  Obj 0 Primal inf 0.51643295 (2)
# 5  Obj 0.12971431
# Optimal - objective value 0.12971141
# Optimal objective 0.1297114084 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fa7324b509a94eeb8f9db82d79d8a963-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fa7324b509a94eeb8f9db82d79d8a963-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.0376311 - largest nonzero change 2.2831679e-05 ( 0.0011205011%) - largest zero change 2.2709388e-05
# 0  Obj 0 Primal inf 0.62658977 (2)
# 6  Obj 0.080897212
# Optimal - objective value 0.080895346
# Optimal objective 0.08089534637 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/43c3d2512325462c8fc64882d2d21044-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/43c3d2512325462c8fc64882d2d21044-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.3726793 - largest nonzero change 2.5427686e-05 ( 0.0010716866%) - largest zero change 2.5248477e-05
# 0  Obj 0 Primal inf 0.26306657 (2)
# 7  Obj 0.035770702
# Optimal - objective value 0.035769603
# Optimal objective 0.03576960274 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4c96b4bd0b354110b71727a3d545650d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4c96b4bd0b354110b71727a3d545650d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7152956 - largest nonzero change 2.8082333e-05 ( 0.0010342275%) - largest zero change 2.7612954e-05
# 0  Obj 0 Primal inf 0.66901547 (2)
# 8  Obj 0.12423856
# Optimal - objective value 0.12423507
# Optimal objective 0.1242350662 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/94f8ffb45ebc4835848bb5c205b6a395-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/94f8ffb45ebc4835848bb5c205b6a395-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 6.6852811 - largest nonzero change 5.8842422e-05 ( 0.00088017873%) - largest zero change 5.7114024e-05
# 0  Obj 0 Primal inf 2.5687728 (2)
# 5  Obj 1.0000257
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1a802f9b251a465e9d1be6b785147473-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1a802f9b251a465e9d1be6b785147473-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.7983761 - largest nonzero change 3.6474216e-05 ( 0.00096025813%) - largest zero change 3.6468814e-05
# 0  Obj 0 Primal inf 0.80676614 (2)
# 6  Obj 0.17465974
# Optimal - objective value 0.17465521
# Optimal objective 0.1746552074 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7693d9155445484a864da653541d2846-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7693d9155445484a864da653541d2846-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7078688 - largest nonzero change 2.8024789e-05 ( 0.0010349389%) - largest zero change 2.7596826e-05
# 0  Obj 0 Primal inf 1.2017162 (2)
# 6  Obj 0.25022812
# Optimal - objective value 0.25022183
# Optimal objective 0.2502218275 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Malmquist Index (MI): [ 0.95267471  1.1082398   2.3805533   2.41092201  0.99870514  0.97388023
#   0.99631445  1.14684887  0.83055346  0.73132855  0.97697781  1.34994728
#   0.75912004  1.14519252  0.5028936   0.42697876  0.30036482  0.25268717
#   0.29530929  1.         13.08584765  1.75482257  0.87497851  2.29203961
#   0.9506707   8.59188411  0.64468401  0.87906667  0.88403013  1.1298012 ]
# Efficiency Change (EC): [ 1.          1.18035815  2.6037932   2.61326951  2.13713794  0.61032081
#   0.99112924  1.14763338  0.74704433  0.76050817  1.04521433  1.90200524
#   0.70532448  1.31146592  0.50274854  0.35295142  0.24606141  0.20408776
#   0.23311726  1.         19.65715531  1.62261506  0.21734334  3.89348969
#   1.15464802 12.32813689  0.20472941  1.16169441  1.01138423  1.29131997]
# Technological Change (TC): [0.95267471 0.93890129 0.91426358 0.92256922 0.46730963 1.59568575
#  1.00523161 0.99931641 1.11178604 0.96163141 0.93471529 0.70974951
#  1.07627065 0.87321562 1.00028854 1.20973806 1.22069047 1.23812997
#  1.2667843  1.         0.66570404 1.08147805 4.02578938 0.58868516
#  0.82334242 0.69693289 3.14895654 0.75671077 0.87407941 0.87491964]

# %%
Final_MI = MI_Stage1 * MI_Stage2
Final_MI
# Out:
# array([ 0.93084102,  1.2914316 ,  2.96124375,  2.63096796,  0.99160147,
#         1.67584459,  1.49921598,  1.35613913,  0.98212248,  0.74970269,
#         0.67692616,  0.9353484 ,  0.75912004,  1.14519252,  1.30442732,
#         1.10751611,  0.77909934,  0.65543099,  0.76598608,  1.85773261,
#        13.08584765,  1.99151607,  2.33796124,  2.47163154,  0.86215891,
#        13.5540653 ,  0.67760075,  0.87906667,  0.85792253,  1.43928625])

# %%
#import all the necessary libraries
from pulp import LpProblem, LpMinimize, LpVariable, lpSum, value
import pandas as pd
import numpy as np

# %% [markdown]
# Part 1: Two Stage DEA

# %%
#define a function to solve the DEA problem using PuLP
def calculate_efficiency(inputs, outputs):
    #Determine the deminsion of the problem by inspecting number of imports, outputs and DMUs
    num_dmu = inputs.shape[0]
    num_inputs = inputs.shape[1]
    num_outputs = outputs.shape[1]
    #Initiate the variables for storing the results
    efficiency_scores = np.zeros(num_dmu)

    for i in range(num_dmu):
        # create the LP problem
        model = LpProblem(f"DEA_DMU_{i}", LpMinimize)

        # define the variables
        theta = LpVariable("theta", lowBound=0)  # efficiency score
        lambdas = [LpVariable(f"lambda_{j}", lowBound=0) for j in range(num_dmu)] # efficiency weights

        # objective function: minimise the efficiency score
        model += theta

        # Constraint 1: Limit the total weighted sum of all DMU input to be less than θ times the inputs of the evaluated DMU
        for j in range(num_inputs):
            model += lpSum(lambdas[k] * inputs[k, j] for k in range(num_dmu)) <= theta * inputs[i, j]

        # Constraint 2: Ensure that the weighted sum of all DMU output is greater or equal to the evaluated DMU
        for j in range(num_outputs):
            model += lpSum(lambdas[k] * outputs[k, j] for k in range(num_dmu)) >= outputs[i, j]
        #solve the problem and store the efficiency score
        model.solve()
        efficiency_scores[i] = value(theta)

    return efficiency_scores

# %%
# read 2023 data
df_2023 = pd.read_excel("DATA.xlsx", sheet_name="2023")
# Invert the values of the Airline_CPE column
df_2023['Airline_CPE'] = 1/df_2023['Airline_CPE']

# Stage one inputs and outputs
inputs_stage1 = df_2023[['operating_expense', 'Terminal_Size']].values
outputs_stage1 = df_2023[['Total_Aircraft_Movements', 'Enplanement']].values
# Calculate stage one efficiency scores
df_2023['Airport_Efficiency'] = calculate_efficiency(inputs_stage1, outputs_stage1)

# Stage two inputs and outputs
inputs_stage2 = df_2023[['Airport_Efficiency','Operation_Cost']].values
outputs_stage2 = df_2023[['On_Time_Performance_Rate','Airline_CPE']].values

# Calculate stage two efficiency scores
df_2023['Airline_Efficiency'] = calculate_efficiency(inputs_stage2, outputs_stage2)
df_2023['Overall_Efficiency'] = df_2023['Airline_Efficiency'] * df_2023['Airport_Efficiency']

# Save the results as CSV
df_2023[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency', 'Overall_Efficiency']].to_csv("dea_results_2023.csv", index=False)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a1c35ca7bc2c47c88214f3a56ab89a1c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a1c35ca7bc2c47c88214f3a56ab89a1c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.0244293 - largest nonzero change 2.6861018e-05 ( 0.00044586825%) - largest zero change 1.5314754e-05
# 0  Obj 0 Primal inf 10.21783 (2)
# 6  Obj 0.69302432
# Optimal - objective value 0.69299985
# Optimal objective 0.6929998467 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4f005a8b376348ceb8d0257314455bbf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4f005a8b376348ceb8d0257314455bbf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.2019113 - largest nonzero change 1.2052274e-05 ( 0.00054735511%) - largest zero change 1.1661524e-05
# 0  Obj 0 Primal inf 12.501083 (2)
# 5  Obj 0.59283494
# Optimal - objective value 0.59281696
# Optimal objective 0.5928169596 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/673e3f9ea0d9445987fe1d99e2a3033d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/673e3f9ea0d9445987fe1d99e2a3033d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.6058328 - largest nonzero change 2.136526e-05 ( 0.00046387399%) - largest zero change 1.3958983e-05
# 0  Obj 0 Primal inf 4.3292418 (2)
# 5  Obj 0.77499352
# Optimal - objective value 0.77497756
# Optimal objective 0.7749775586 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/25b32076cdf14b40b8371acbd98061fc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/25b32076cdf14b40b8371acbd98061fc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 4.3856299 (2)
# 7  Obj 0.35014887
# Optimal - objective value 0.35013535
# Optimal objective 0.3501353504 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ec76b21eed49497f98055ea122aec206-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ec76b21eed49497f98055ea122aec206-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.1515819 - largest nonzero change 1.1857294e-05 ( 0.00055109656%) - largest zero change 1.1613424e-05
# 0  Obj 0 Primal inf 1.5328771 (2)
# 5  Obj 0.30745258
# Optimal - objective value 0.30744438
# Optimal objective 0.3074443811 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/81bd7906525148798fab8eb8fc1a95eb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/81bd7906525148798fab8eb8fc1a95eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.1047645 - largest nonzero change 2.7172243e-05 ( 0.00044509895%) - largest zero change 1.5391531e-05
# 0  Obj 0 Primal inf 1.8338325 (2)
# 8  Obj 0.38633478
# Optimal - objective value 0.38632943
# Optimal objective 0.386329425 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ffabf31c6ed048dd9eb5552c0a34a4cd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ffabf31c6ed048dd9eb5552c0a34a4cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.85188983 - largest nonzero change 6.8221818e-06 ( 0.00080082911%) - largest zero change 5.9448044e-06
# 0  Obj 0 Primal inf 4.1231454 (2)
# 7  Obj 0.097504378
# Optimal - objective value 0.097501005
# Optimal objective 0.09750100516 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/70b580b34561427da8611e403af3de1d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/70b580b34561427da8611e403af3de1d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 7.5305366 - largest nonzero change 3.2695799e-05 ( 0.00043417622%) - largest zero change 1.675416e-05
# 0  Obj 0 Primal inf 1.8609596 (2)
# 5  Obj 0.20957036
# Optimal - objective value 0.20956602
# Optimal objective 0.2095660196 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5fab93a4e17a4224929e3d246d6b1287-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5fab93a4e17a4224929e3d246d6b1287-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 7.5305366 - largest nonzero change 3.2695799e-05 ( 0.00043417622%) - largest zero change 1.675416e-05
# 0  Obj 0 Primal inf 2.1443285 (2)
# 5  Obj 0.21796493
# Optimal - objective value 0.21795983
# Optimal objective 0.217959829 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d9397041bccd4e7082b6c868a2a68427-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d9397041bccd4e7082b6c868a2a68427-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.1515819 - largest nonzero change 1.1857294e-05 ( 0.00055109656%) - largest zero change 1.1613424e-05
# 0  Obj 0 Primal inf 1.5474722 (2)
# 7  Obj 0.16246321
# Optimal - objective value 0.16245906
# Optimal objective 0.162459063 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ea11cd1521d645c397124edf8c6da22a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ea11cd1521d645c397124edf8c6da22a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.75060335 - largest nonzero change 6.4297897e-06 ( 0.00085661618%) - largest zero change 5.8893183e-06
# 0  Obj 0 Primal inf 6.4385864 (2)
# 6  Obj 0.16327063
# Optimal - objective value 0.16326603
# Optimal objective 0.1632660287 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88e7fe036c9d472dabc43ddf10f6e639-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88e7fe036c9d472dabc43ddf10f6e639-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.75060335 - largest nonzero change 6.4297897e-06 ( 0.00085661618%) - largest zero change 5.8893183e-06
# 0  Obj 0 Primal inf 2.4337638 (2)
# 6  Obj 0.14664224
# Optimal - objective value 0.14663868
# Optimal objective 0.146638677 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d0b56d20d51743bbb011392e7a95a69a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d0b56d20d51743bbb011392e7a95a69a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.1836315 - largest nonzero change 1.9729618e-05 ( 0.00047159073%) - largest zero change 1.355548e-05
# 0  Obj 0 Primal inf 5.2680478 (2)
# 5  Obj 1.0000134
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f6f60e92dda7459189034f047443afea-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f6f60e92dda7459189034f047443afea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.570482 - largest nonzero change 4.8346876e-05 ( 0.00041784667%) - largest zero change 2.0615188e-05
# 0  Obj 0 Primal inf 11.022406 (2)
# 5  Obj 1.0000349
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/49c36ddc6e634ef5bf82f2deb9dedd47-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/49c36ddc6e634ef5bf82f2deb9dedd47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.4831368 (2)
# 6  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f7ef259a63d64b94808b5de99f509b51-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f7ef259a63d64b94808b5de99f509b51-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.7719331 (2)
# 6  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/03e7d9d9f7264e83970a30b64a97ff9b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/03e7d9d9f7264e83970a30b64a97ff9b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.9011465 (2)
# 7  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ae9ece97208e44f3954444c03facac1b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ae9ece97208e44f3954444c03facac1b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 2.0382028 (2)
# 7  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2e0636d6486e41ae802379e7127aa2cb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2e0636d6486e41ae802379e7127aa2cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 1.9060518 (2)
# 7  Obj 0.17648419
# Optimal - objective value 0.1764774
# Optimal objective 0.1764774048 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/004050532d8f4a92a84b06f3e8527fd8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/004050532d8f4a92a84b06f3e8527fd8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.3170882 - largest nonzero change 1.2498479e-05 ( 0.00053940453%) - largest zero change 1.17716e-05
# 0  Obj 0 Primal inf 0.91586435 (2)
# 5  Obj 0.087443529
# Optimal - objective value 0.087440621
# Optimal objective 0.08744062057 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c7cea3c8c2c74db3a5b023a84f345988-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c7cea3c8c2c74db3a5b023a84f345988-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.2874785 - largest nonzero change 1.2383768e-05 ( 0.00054137201%) - largest zero change 1.1743302e-05
# 0  Obj 0 Primal inf 2.0223382 (2)
# 6  Obj 0.55980088
# Optimal - objective value 0.55979383
# Optimal objective 0.559793832 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4db95bec7af74b978c145640d40a7294-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4db95bec7af74b978c145640d40a7294-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 7.5305366 - largest nonzero change 3.2695799e-05 ( 0.00043417622%) - largest zero change 1.675416e-05
# 0  Obj 0 Primal inf 3.8954224 (2)
# 5  Obj 0.37063606
# Optimal - objective value 0.37062653
# Optimal objective 0.3706265288 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5d73325d814e4fe28bbe0aeba792e55f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5d73325d814e4fe28bbe0aeba792e55f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.0122147 - largest nonzero change 1.5191455e-05 ( 0.00050432843%) - largest zero change 1.2435942e-05
# 0  Obj 0 Primal inf 1.4775207 (2)
# 5  Obj 0.21169775
# Optimal - objective value 0.21169174
# Optimal objective 0.2116917428 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fb0a0d4858c9441aac762f938389643e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fb0a0d4858c9441aac762f938389643e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.9333855 - largest nonzero change 1.1011984e-05 ( 0.00056956998%) - largest zero change 1.1003348e-05
# 0  Obj 0 Primal inf 1.6636339 (2)
# 5  Obj 0.28304772
# Optimal - objective value 0.28303913
# Optimal objective 0.2830391323 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3eb13b92255c492ca7fcb7c43510c5f7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3eb13b92255c492ca7fcb7c43510c5f7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.3309942 - largest nonzero change 8.6782707e-06 ( 0.00065201418%) - largest zero change 8.5505176e-06
# 0  Obj 0 Primal inf 2.4281561 (2)
# 8  Obj 0.14214068
# Optimal - objective value 0.14213529
# Optimal objective 0.1421352879 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6a3f42afe73344979f7098fc4fc88cd8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6a3f42afe73344979f7098fc4fc88cd8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.0244293 - largest nonzero change 2.6861018e-05 ( 0.00044586825%) - largest zero change 1.5314754e-05
# 0  Obj 0 Primal inf 2.281255 (2)
# 5  Obj 0.49533577
# Optimal - objective value 0.49532713
# Optimal objective 0.4953271258 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1e63b72cc8924382bcb688f05e748f74-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1e63b72cc8924382bcb688f05e748f74-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 9.1167243 - largest nonzero change 3.8840819e-05 ( 0.00042603919%) - largest zero change 1.82701e-05
# 0  Obj 0 Primal inf 1.9451359 (2)
# 7  Obj 0.48946685
# Optimal - objective value 0.48946008
# Optimal objective 0.4894600782 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ef01f319fa77497ba2352f9db1c7fbbc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ef01f319fa77497ba2352f9db1c7fbbc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 12.268493 - largest nonzero change 5.1051024e-05 ( 0.00041611488%) - largest zero change 2.1282286e-05
# 0  Obj 0 Primal inf 3.6150119 (2)
# 5  Obj 1.0000107
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88dfe4dde536485aa1e02667fe284a45-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88dfe4dde536485aa1e02667fe284a45-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.5061073 - largest nonzero change 9.3566732e-06 ( 0.00062124877%) - largest zero change 9.2522962e-06
# 0  Obj 0 Primal inf 2.0132583 (2)
# 9  Obj 0.094970041
# Optimal - objective value 0.094966178
# Optimal objective 0.09496617791 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/744bb43d7178401180d326cd1d25707c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/744bb43d7178401180d326cd1d25707c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.2148637 - largest nonzero change 1.2102453e-05 ( 0.00054641975%) - largest zero change 1.1673903e-05
# 0  Obj 0 Primal inf 2.3205611 (2)
# 5  Obj 0.37627014
# Optimal - objective value 0.3762612
# Optimal objective 0.3762612036 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5cb6bf38db5e4e21b56e0c9f363a1865-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5cb6bf38db5e4e21b56e0c9f363a1865-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.269591 - largest nonzero change 1.6188552e-05 ( 0.00049512467%) - largest zero change 1.2681919e-05
# 0  Obj 0 Primal inf 2.9953952 (2)
# 5  Obj 0.30633761
# Optimal - objective value 0.30632964
# Optimal objective 0.3063296428 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f6ffc746c5b64398940943883557c0c5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f6ffc746c5b64398940943883557c0c5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.269591 - largest nonzero change 1.6188552e-05 ( 0.00049512467%) - largest zero change 1.2681919e-05
# 0  Obj 0 Primal inf 2.9953952 (2)
# 5  Obj 0.35810593
# Optimal - objective value 0.35809771
# Optimal objective 0.3580977112 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/86a92466564d4fb7912d7bfd59da69c2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/86a92466564d4fb7912d7bfd59da69c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.8217517 - largest nonzero change 1.4453586e-05 ( 0.00051222033%) - largest zero change 1.2253914e-05
# 0  Obj 0 Primal inf 0.56802118 (2)
# 8  Obj 0.046147018
# Optimal - objective value 0.046145692
# Optimal objective 0.04614569221 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bf5c5fd448a744bfa71982dde7dd2069-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bf5c5fd448a744bfa71982dde7dd2069-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.8217517 - largest nonzero change 1.4453586e-05 ( 0.00051222033%) - largest zero change 1.2253914e-05
# 0  Obj 0 Primal inf 0.56802118 (2)
# 8  Obj 0.1021389
# Optimal - objective value 0.10213729
# Optimal objective 0.1021372905 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a6d69f39610f4bcca2ff79692f614e44-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a6d69f39610f4bcca2ff79692f614e44-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.613581 - largest nonzero change 3.6891601e-05 ( 0.00042829574%) - largest zero change 1.778924e-05
# 0  Obj 0 Primal inf 0.32110993 (2)
# 6  Obj 0.080527013
# Optimal - objective value 0.080525766
# Optimal objective 0.08052576553 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/09b1b102a44847508c23b7f749e14e34-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/09b1b102a44847508c23b7f749e14e34-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.1289082 - largest nonzero change 1.1769454e-05 ( 0.00055283991%) - largest zero change 1.1591754e-05
# 0  Obj 0 Primal inf 0.35722822 (2)
# 7  Obj 0.054348763
# Optimal - objective value 0.054347802
# Optimal objective 0.05434780225 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b83844a61d824a49a5a8d02eba6ea77b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b83844a61d824a49a5a8d02eba6ea77b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.3594547 - largest nonzero change 2.0410772e-05 ( 0.00046819552%) - largest zero change 1.3723516e-05
# 0  Obj 0 Primal inf 1.0859927 (2)
# 6  Obj 0.72202632
# Optimal - objective value 0.72202062
# Optimal objective 0.722020623 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/65ea01e02f5e4cec9dabfa69f887541f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/65ea01e02f5e4cec9dabfa69f887541f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 10.250227 - largest nonzero change 4.32321e-05 ( 0.00042176724%) - largest zero change 1.9353403e-05
# 0  Obj 0 Primal inf 1.5168531 (2)
# 5  Obj 0.49548674
# Optimal - objective value 0.49547984
# Optimal objective 0.495479837 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ae9534f413df489c9a7a29b34d1777ea-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ae9534f413df489c9a7a29b34d1777ea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.3030432 - largest nonzero change 2.0192229e-05 ( 0.00046925462%) - largest zero change 1.3669603e-05
# 0  Obj 0 Primal inf 0.86479563 (2)
# 6  Obj 0.2530109
# Optimal - objective value 0.25300787
# Optimal objective 0.2530078717 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f56c16aa8f3040b9822ffcbe65775fee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f56c16aa8f3040b9822ffcbe65775fee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.5406197 - largest nonzero change 1.7238539e-05 ( 0.00048687914%) - largest zero change 1.2940945e-05
# 0  Obj 0 Primal inf 0.5098714 (2)
# 7  Obj 0.18927032
# Optimal - objective value 0.18926835
# Optimal objective 0.1892683546 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/873e9195debf475ab232bfd9a7fc023c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/873e9195debf475ab232bfd9a7fc023c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.8179625 - largest nonzero change 1.4438906e-05 ( 0.00051238816%) - largest zero change 1.2250292e-05
# 0  Obj 0 Primal inf 1.3850184 (2)
# ...
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.57047 - largest nonzero change 4.834683e-05 ( 0.0004178467%) - largest zero change 2.0615177e-05
# 0  Obj 0 Primal inf 0.72749869 (2)
# 8  Obj 0.26188151
# Optimal - objective value 0.26187808
# Optimal objective 0.2618780782 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/32dbe21d9f0b4b2d8237e65ea5562287-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/32dbe21d9f0b4b2d8237e65ea5562287-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.5605846 - largest nonzero change 3.6686288e-05 ( 0.00042854887%) - largest zero change 1.773859e-05
# 0  Obj 0 Primal inf 0.6957861 (2)
# 8  Obj 0.24883764
# Optimal - objective value 0.24883464
# Optimal objective 0.2488346423 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e422b741a6a1498fae355cd580d9ad76-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e422b741a6a1498fae355cd580d9ad76-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 10.782694 - largest nonzero change 4.5294919e-05 ( 0.00042007053%) - largest zero change 1.9862289e-05
# 0  Obj 0 Primal inf 0.70855711 (2)
# 8  Obj 0.25322622
# Optimal - objective value 0.25322296
# Optimal objective 0.2532229588 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8194feb479cc4192af9bd621abc4c5d1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8194feb479cc4192af9bd621abc4c5d1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 30.285662 - largest nonzero change 1.2085099e-05 ( 3.9903699e-05%) - largest zero change 1.1034501e-05
# 0  Obj 0 Primal inf 1.3487604 (2)
# 5  Obj 1.0000024
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ab9c11d6ffda40b995210de1475c7043-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ab9c11d6ffda40b995210de1475c7043-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.730665 - largest nonzero change 2.184887e-05 ( 0.00046185622%) - largest zero change 1.4078287e-05
# 0  Obj 0 Primal inf 1.3819519 (2)
# 6  Obj 0.43249687
# Optimal - objective value 0.43249179
# Optimal objective 0.4324917877 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/923bfd176833430386a3851d85819ce8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/923bfd176833430386a3851d85819ce8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.3796103 - largest nonzero change 2.0488856e-05 ( 0.00046782372%) - largest zero change 1.3742779e-05
# 0  Obj 0 Primal inf 1.4752245 (2)
# 5  Obj 0.26710265
# Optimal - objective value 0.26709814
# Optimal objective 0.267098139 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/16ef2fae41f642848fb85ed5727026c2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/16ef2fae41f642848fb85ed5727026c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 12.509685 - largest nonzero change 5.1985424e-05 ( 0.0004155614%) - largest zero change 2.1512797e-05
# 0  Obj 0 Primal inf 0.52888658 (2)
# 6  Obj 0.21734603
# Optimal - objective value 0.21734334
# Optimal objective 0.2173433361 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2bea3cec31a14abd8353e1124f022580-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2bea3cec31a14abd8353e1124f022580-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 9.3562931 - largest nonzero change 3.9768928e-05 ( 0.00042505004%) - largest zero change 1.8499059e-05
# 0  Obj 0 Primal inf 0.48887125 (2)
# 7  Obj 0.30461538
# Optimal - objective value 0.30461266
# Optimal objective 0.3046126603 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/90d386a756ee422a8a375c42bb4fad6d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/90d386a756ee422a8a375c42bb4fad6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.6273534 - largest nonzero change 1.7574552e-05 ( 0.00048450068%) - largest zero change 1.3023838e-05
# 0  Obj 0 Primal inf 0.44813714 (2)
# 7  Obj 0.19236671
# Optimal - objective value 0.19236486
# Optimal objective 0.1923648591 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f11c8aff0d48475a88c72ae6efb1b7d1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f11c8aff0d48475a88c72ae6efb1b7d1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 5.3463598 - largest nonzero change 2.4234122e-05 ( 0.00045328266%) - largest zero change 1.4666714e-05
# 0  Obj 0 Primal inf 1.0831225 (2)
# 7  Obj 0.17768124
# Optimal - objective value 0.17767796
# Optimal objective 0.177677964 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e9c906ec0d3d459a929b03c9f4f3722d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e9c906ec0d3d459a929b03c9f4f3722d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.6457145 - largest nonzero change 1.3771603e-05 ( 0.00052052493%) - largest zero change 1.2085673e-05
# 0  Obj 0 Primal inf 0.41120919 (2)
# 7  Obj 0.051155124
# Optimal - objective value 0.051154073
# Optimal objective 0.05115407284 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c26610d71eb4960b7c3a871c39928d5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c26610d71eb4960b7c3a871c39928d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.6481971 - largest nonzero change 1.3781221e-05 ( 0.00052040014%) - largest zero change 1.2088045e-05
# 0  Obj 0 Primal inf 1.5938966 (2)
# 6  Obj 0.17402657
# Optimal - objective value 0.17402254
# Optimal objective 0.1740225354 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e5543afad3e4448985b5026b75a8917c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e5543afad3e4448985b5026b75a8917c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.11473 - largest nonzero change 1.9462688e-05 ( 0.00047300038%) - largest zero change 1.348963e-05
# 0  Obj 0 Primal inf 0.61417374 (2)
# 8  Obj 0.40403072
# Optimal - objective value 0.40402751
# Optimal objective 0.4040275133 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7fca2dd421cd46fd9041b49638275b76-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7fca2dd421cd46fd9041b49638275b76-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 7.038188 - largest nonzero change 3.0788401e-05 ( 0.00043744783%) - largest zero change 1.6283616e-05
# 0  Obj 0 Primal inf 0.89165993 (2)
# 6  Obj 0.1523971
# Optimal - objective value 0.15239417
# Optimal objective 0.1523941693 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
df_2023[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency','Overall_Efficiency']]
# Out:
#                                          Hub Airport               Airline  \
# 0               Chicago Midway International Airport    SouthWest Airlines
# 1   Hartsfield-Jackson Atlanta International Airport    SouthWest Airlines
# 2                       Denver International Airport     Frontier Airlines
# 3              Dallas/Ft Worth International Airport     Frontier Airlines
# 4       Minneapolis-Saint Paul International Airport  Sun Country Airlines
# 5                                    Abudabi Airport            Air Arabia
# 6              John F. Kennedy International Airport       JetBlue Airways
# 7                            Ankara Esenboga Airport           Anadolu Jet
# 8                            Ankara Esenboga Airport      Pegasus Airlines
# 9                                 Dusseldorf Airport             Eurowings
# 10               Indira Gandhi International Airport                IndiGo
# 11               Indira Gandhi International Airport              SpiceJet
# 12                                    Geneva Airport               EasyJet
# 13                                    Dublin Airport               Ryanair
# 14                     Incheon International Airport             Air Seoul
# 15                     Incheon International Airport             Air Busan
# 16                     Incheon International Airport               Jin Air
# 17                     Incheon International Airport              Jeju Air
# 18                     Incheon International Airport        T'way Airlines
# 19                      Narita International Airport         Jetstar Japan
# 20                                    Changi Airport                 Scoot
# 21       Budapest Ferenc Liszt International Airport              Wizz Air
# 22                    HongKong International Airport            HK Express
# 23             Toronto Pearson International Airport               WestJet
# 24        Aeropuerto de Adolfo Suárez Madrid-Barajas            Air Europa
# 25                              Suvarnabhumi Airport          Thai AirAsia
# 26                                 Melbourne Airport     Jetstar Australia
# 27   Fort Lauderdale-Hollywood International Airport        Spirit Airline
# 28                            Aéroport de Paris-Orly      Transavia France
# 29            The Ninoy Aquino International Airport      Cebu Pacific Air
#
#     Airport_Efficiency  Airline_Efficiency  Overall_Efficiency
# 0             0.693000            0.306330            0.212286
# 1             0.592817            0.358098            0.212286
# 2             0.774978            0.046146            0.035762
# 3             0.350135            0.102137            0.035762
# 4             0.307444            0.080526            0.024757
# 5             0.386329            0.054348            0.020996
# 6             0.097501            0.722021            0.070398
# 7             0.209566            0.495480            0.103836
# 8             0.217960            0.253008            0.055146
# 9             0.162459            0.189268            0.030748
# 10            0.163266            0.554608            0.090549
# 11            0.146639            0.288492            0.042304
# 12            1.000000            0.050757            0.050757
# 13            1.000000            1.000000            1.000000
# 14            0.176477            0.502749            0.088724
# 15            0.176477            0.327192            0.057742
# 16            0.176477            0.261878            0.046216
# 17            0.176477            0.248835            0.043914
# 18            0.176477            0.253223            0.044688
# 19            0.087441            1.000000            0.087441
# 20            0.559794            0.432492            0.242106
# 21            0.370627            0.267098            0.098994
# 22            0.211692            0.217343            0.046010
# 23            0.283039            0.304613            0.086217
# 24            0.142135            0.192365            0.027342
# 25            0.495327            0.177678            0.088009
# 26            0.489460            0.051154            0.025038
# 27            1.000000            0.174023            0.174023
# 28            0.094966            0.404028            0.038369
# 29            0.376261            0.152394            0.057340

# %%
# read 2022 data
df_2022 = pd.read_excel("DATA.xlsx", sheet_name="2022")
df_2022['Airline_CPE'] = 1/df_2022['Airline_CPE']

# Stage 1 DEA calculation
inputs_stage1 = df_2022[['operating_expense', 'Terminal_Size']].values
outputs_stage1 = df_2022[['Total_Aircraft_Movements', 'Enplanement']].values

df_2022['Airport_Efficiency'] = calculate_efficiency(inputs_stage1, outputs_stage1)

# Stage 2 DEA calculation
inputs_stage2 = df_2022[['Airport_Efficiency','Operation_Cost']].values
outputs_stage2 = df_2022[['On_Time_Performance_Rate','Airline_CPE']].values

# Calculate stage two efficiency scores
df_2022['Airline_Efficiency'] = calculate_efficiency(inputs_stage2, outputs_stage2)
df_2022['Overall_Efficiency'] = df_2022['Airline_Efficiency'] * df_2022['Airport_Efficiency']

# Save the results as CSV
df_2022[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency', 'Overall_Efficiency']].to_csv("dea_results_2022.csv", index=False)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cde95cd1c22a4fcca7b1571498e799a4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cde95cd1c22a4fcca7b1571498e799a4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.6581377 - largest nonzero change 2.9316055e-05 ( 0.00044030413%) - largest zero change 1.5920397e-05
# 0  Obj 0 Primal inf 18.790759 (2)
# 6  Obj 1.0000415
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6df3f89e2bb74c7591300d0af2d37d82-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6df3f89e2bb74c7591300d0af2d37d82-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.4335299 - largest nonzero change 1.2949583e-05 ( 0.00053213167%) - largest zero change 1.1882885e-05
# 0  Obj 0 Primal inf 22.159438 (2)
# 6  Obj 0.57435991
# Optimal - objective value 0.57433335
# Optimal objective 0.5743333504 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5cbd912b438748c89a0fdac7094d1c51-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5cbd912b438748c89a0fdac7094d1c51-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 5.0903194 - largest nonzero change 2.32422e-05 ( 0.00045659611%) - largest zero change 1.4422013e-05
# 0  Obj 0 Primal inf 7.2657163 (2)
# 6  Obj 0.69681933
# Optimal - objective value 0.69679549
# Optimal objective 0.6967954865 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/08ac8cdd2f9841a8b60b77c1866d4d64-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/08ac8cdd2f9841a8b60b77c1866d4d64-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 7.5460553 (2)
# 6  Obj 0.3446172
# Optimal - objective value 0.34459536
# Optimal objective 0.3445953585 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/765877b0167c46b3822970facc6796fb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/765877b0167c46b3822970facc6796fb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.3779063 - largest nonzero change 1.2734093e-05 ( 0.00053551702%) - largest zero change 1.1829725e-05
# 0  Obj 0 Primal inf 6.9229709 (2)
# 6  Obj 0.29654196
# Optimal - objective value 0.29652927
# Optimal objective 0.2965292741 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2c2c0fc3797a45b2933b0a15d4bd7872-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2c2c0fc3797a45b2933b0a15d4bd7872-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.2536822 - largest nonzero change 3.5497324e-05 ( 0.00043007863%) - largest zero change 1.744528e-05
# 0  Obj 0 Primal inf 2.9335864 (2)
# 7  Obj 0.36618719
# Optimal - objective value 0.36617929
# Optimal objective 0.3661792875 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/47a604657a8f472a9aa754f5a5fb37d5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/47a604657a8f472a9aa754f5a5fb37d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.0236683 - largest nonzero change 7.4876654e-06 ( 0.00073145427%) - largest zero change 7.2443821e-06
# 0  Obj 0 Primal inf 7.3923521 (2)
# 7  Obj 0.07024456
# Optimal - objective value 0.070237907
# Optimal objective 0.07023790685 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e53dd50fe18d4a0b8e727eb339036e00-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e53dd50fe18d4a0b8e727eb339036e00-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.3226721 - largest nonzero change 3.5764596e-05 ( 0.00042972492%) - largest zero change 1.7511214e-05
# 0  Obj 0 Primal inf 2.6960358 (2)
# 5  Obj 0.17959813
# Optimal - objective value 0.1795931
# Optimal objective 0.1795931008 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6b959e99181d44ed9a75e7354e58c529-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6b959e99181d44ed9a75e7354e58c529-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.3226721 - largest nonzero change 3.5764596e-05 ( 0.00042972492%) - largest zero change 1.7511214e-05
# 0  Obj 0 Primal inf 4.2213957 (2)
# 5  Obj 0.240906
# Optimal - objective value 0.24089743
# Optimal objective 0.2408974254 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de24c793264f444094a00644f5b8ce73-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/de24c793264f444094a00644f5b8ce73-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.3779063 - largest nonzero change 1.2734093e-05 ( 0.00053551702%) - largest zero change 1.1829725e-05
# 0  Obj 0 Primal inf 3.2197925 (2)
# 6  Obj 0.15952188
# Optimal - objective value 0.15951551
# Optimal objective 0.159515511 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/82237737108541758a442c6a9ef399de-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/82237737108541758a442c6a9ef399de-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.87325018 - largest nonzero change 6.9049335e-06 ( 0.00079071653%) - largest zero change 6.8586978e-06
# 0  Obj 0 Primal inf 9.0652209 (2)
# 7  Obj 0.14649317
# Optimal - objective value 0.14648794
# Optimal objective 0.1464879443 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6065db3f0d40416e807f314c9b1109be-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6065db3f0d40416e807f314c9b1109be-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 0.87325018 - largest nonzero change 6.9049335e-06 ( 0.00079071653%) - largest zero change 6.8586978e-06
# 0  Obj 0 Primal inf 3.7815523 (2)
# 6  Obj 0.14649316
# Optimal - objective value 0.14648794
# Optimal objective 0.1464879443 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7381e5eec05242959f17615ca8262bf3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7381e5eec05242959f17615ca8262bf3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.6237067 - largest nonzero change 2.1434505e-05 ( 0.00046357839%) - largest zero change 1.3976065e-05
# 0  Obj 0 Primal inf 10.790385 (2)
# 5  Obj 1.0000197
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4d94022ec82948cf8a2d289b65760a53-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4d94022ec82948cf8a2d289b65760a53-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.854493 - largest nonzero change 4.9447155e-05 ( 0.00041711742%) - largest zero change 2.0886621e-05
# 0  Obj 0 Primal inf 14.876567 (2)
# 6  Obj 1.0000374
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2cdbee95e03d4c1ead398d3429ca9674-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2cdbee95e03d4c1ead398d3429ca9674-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 1.2887257 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b1f25fc6112c4c1f962d58c193bf92e2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b1f25fc6112c4c1f962d58c193bf92e2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 1.8101683 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6dae7a6a7242482ba5e2d929552e95cc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6dae7a6a7242482ba5e2d929552e95cc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 2.0138833 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d742f82e076141bfb993bd8e21475ea1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d742f82e076141bfb993bd8e21475ea1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 2.1410492 (2)
# 8  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c4077d7eff4451d8329833e2451a7a7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0c4077d7eff4451d8329833e2451a7a7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 1.8831999 (2)
# 6  Obj 0.087263737
# Optimal - objective value 0.087258152
# Optimal objective 0.08725815239 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b20f2c2ac8ad44668ab354b1ddcca3a1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b20f2c2ac8ad44668ab354b1ddcca3a1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.5608222 - largest nonzero change 1.3442724e-05 ( 0.00052493781%) - largest zero change 1.200454e-05
# 0  Obj 0 Primal inf 1.2602406 (2)
# 6  Obj 0.089766423
# Optimal - objective value 0.089762283
# Optimal objective 0.08976228302 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/15b4412d0a874fbcab310b34355fc4ac-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/15b4412d0a874fbcab310b34355fc4ac-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 4.5935094 - largest nonzero change 2.1317518e-05 ( 0.00046407913%) - largest zero change 1.3947205e-05
# 0  Obj 0 Primal inf 2.4799394 (2)
# 7  Obj 0.38453915
# Optimal - objective value 0.38453164
# Optimal objective 0.384531644 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/783fbf0ff4ee4d4a9322dd489ff00c02-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/783fbf0ff4ee4d4a9322dd489ff00c02-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 8.3226721 - largest nonzero change 3.5764596e-05 ( 0.00042972492%) - largest zero change 1.7511214e-05
# 0  Obj 0 Primal inf 4.5273562 (2)
# 5  Obj 0.33312871
# Optimal - objective value 0.33312014
# Optimal objective 0.3331201423 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ca13d6644d14efb88b5cc83ea751b1f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ca13d6644d14efb88b5cc83ea751b1f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 3.3290689 - largest nonzero change 1.6418974e-05 ( 0.00049320018%) - largest zero change 1.2738763e-05
# 0  Obj 0 Primal inf 1.004552 (2)
# 6  Obj 0.10872938
# Optimal - objective value 0.10872423
# Optimal objective 0.1087242289 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e0477dabcb6d4fc28100f6d3144c1016-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e0477dabcb6d4fc28100f6d3144c1016-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.9565443 - largest nonzero change 1.4975783e-05 ( 0.00050652998%) - largest zero change 1.2382737e-05
# 0  Obj 0 Primal inf 2.2457217 (2)
# 6  Obj 0.31942462
# Optimal - objective value 0.31941171
# Optimal objective 0.3194117141 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c84a09fc264941c28903e9d32a98994e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c84a09fc264941c28903e9d32a98994e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.377007 - largest nonzero change 8.8565283e-06 ( 0.00064317233%) - largest zero change 8.8016456e-06
# 0  Obj 0 Primal inf 4.1003095 (2)
# 7  Obj 0.12361996
# Optimal - objective value 0.123612
# Optimal objective 0.1236119988 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3350b26a76584194995d270bfa81b015-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3350b26a76584194995d270bfa81b015-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 6.6581377 - largest nonzero change 2.9316055e-05 ( 0.00044030413%) - largest zero change 1.5920397e-05
# 0  Obj 0 Primal inf 2.722036 (2)
# 8  Obj 0.353109
# Optimal - objective value 0.35309901
# Optimal objective 0.3530990087 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/273d12e846e949c6a2668c2f95732854-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/273d12e846e949c6a2668c2f95732854-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 13.27957 - largest nonzero change 5.4968021e-05 ( 0.00041392921%) - largest zero change 2.2248586e-05
# 0  Obj 0 Primal inf 2.4445741 (2)
# 5  Obj 0.19655582
# Optimal - objective value 0.19654986
# Optimal objective 0.1965498636 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ac6c320d367a41c1b9c7cb812c067bbd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ac6c320d367a41c1b9c7cb812c067bbd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 14.724211 - largest nonzero change 6.0564677e-05 ( 0.00041132713%) - largest zero change 2.3629248e-05
# 0  Obj 0 Primal inf 7.1103941 (2)
# 5  Obj 1.0000167
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/09efe524c04a44b9a8358e6b27a0a386-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/09efe524c04a44b9a8358e6b27a0a386-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 1.6645344 - largest nonzero change 9.9704326e-06 ( 0.00059899227%) - largest zero change 9.8886399e-06
# 0  Obj 0 Primal inf 3.7540063 (2)
# 8  Obj 0.094066082
# Optimal - objective value 0.09405988
# Optimal objective 0.09405987996 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/13444e88050b40baa6cedecccb5c4806-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/13444e88050b40baa6cedecccb5c4806-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 2.4478447 - largest nonzero change 1.300504e-05 ( 0.00053128533%) - largest zero change 1.1896566e-05
# 0  Obj 0 Primal inf 3.5639336 (2)
# 8  Obj 0.33912454
# Optimal - objective value 0.33911205
# Optimal objective 0.3391120505 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0e64f84cfb48485990e45124182e5a63-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0e64f84cfb48485990e45124182e5a63-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.842294 - largest nonzero change 4.9399896e-05 ( 0.00041714803%) - largest zero change 2.0874962e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 3  Obj 0.14861792
# Optimal - objective value 0.14861586
# Optimal objective 0.1486158553 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d9c66d07eb724bd99905c2e7041fd39a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d9c66d07eb724bd99905c2e7041fd39a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 20.6192 - largest nonzero change 8.3402338e-05 ( 0.00040448873%) - largest zero change 2.9263164e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 3  Obj 0.25876543
# Optimal - objective value 0.25876236
# Optimal objective 0.258762364 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7cdb86741e1d4fe0af475a1e5bbde054-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7cdb86741e1d4fe0af475a1e5bbde054-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 12.370452 - largest nonzero change 5.1446023e-05 ( 0.00041587828%) - largest zero change 2.137973e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 4  Obj 0.013584457
# Optimal - objective value 0.013584303
# Optimal objective 0.01358430305 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/07506881b4154cc2b61fab768827030d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/07506881b4154cc2b61fab768827030d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 12.370452 - largest nonzero change 5.1446023e-05 ( 0.00041587828%) - largest zero change 2.137973e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 4  Obj 0.027468606
# Optimal - objective value 0.027468394
# Optimal objective 0.02746839394 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bfd39a58b0b54d27bc203a14f7a3b7c6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bfd39a58b0b54d27bc203a14f7a3b7c6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.842294 - largest nonzero change 4.9399896e-05 ( 0.00041714803%) - largest zero change 2.0874962e-05
# 0  Obj 0 Primal inf 0.093189587 (2)
# 4  Obj 0.043078554
# Optimal - objective value 0.043078246
# Optimal objective 0.04307824589 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/567f5424ae004fabb1cc0e5ef9ab243a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/567f5424ae004fabb1cc0e5ef9ab243a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 25.578673 - largest nonzero change 1.0261574e-05 ( 4.0117694e-05%) - largest zero change 9.7452264e-06
# 0  Obj 0 Primal inf 0.073745763 (2)
# 4  Obj 0.026925607
# Optimal - objective value 0.026925555
# Optimal objective 0.026925555 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b24600c745474a7798d35fbab1bcd66f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b24600c745474a7798d35fbab1bcd66f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 44.103351 - largest nonzero change 1.7438184e-05 ( 3.9539363e-05%) - largest zero change 1.7322207e-05
# 0  Obj 0 Primal inf 0.35428912 (2)
# 4  Obj 0.7357902
# Optimal - objective value 0.7357896
# Optimal objective 0.7357895996 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/031cbf3c480642ea83d720b352ff7056-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/031cbf3c480642ea83d720b352ff7056-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 65.939583 - largest nonzero change 2.5897717e-05 ( 3.9274917e-05%) - largest zero change 2.4952463e-05
# 0  Obj 0 Primal inf 0.36779419 (2)
# 4  Obj 0.29942048
# Optimal - objective value 0.29941991
# Optimal objective 0.2994199108 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b80cd82d10bc4688b071420eb1d4a046-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b80cd82d10bc4688b071420eb1d4a046-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 49.159072 - largest nonzero change 1.9396811e-05 ( 3.9457236e-05%) - largest zero change 1.8940892e-05
# 0  Obj 0 Primal inf 0.28946828 (2)
# 4  Obj 0.17402714
# Optimal - objective value 0.17402679
# Optimal objective 0.1740267909 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7b5d93e5829d4667a8d06912bbf84ea9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7b5d93e5829d4667a8d06912bbf84ea9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 43.294823 - largest nonzero change 1.7124953e-05 ( 3.9554276e-05%) - largest zero change 1.7063342e-05
# 0  Obj 0 Primal inf 0.15566439 (2)
# 4  Obj 0.13678021
# Optimal - objective value 0.13678003
# Optimal objective 0.1367800282 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b9f3b192320d46e4a71fa1c2ec7c691e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b9f3b192320d46e4a71fa1c2ec7c691e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 51.45391 - largest nonzero change 2.028585e-05 ( 3.9425283e-05%) - largest zero change 2.0192716e-05
# 0  Obj 0 Primal inf 0.48737441 (2)
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 135.71562 - largest nonzero change 5.2929517e-05 ( 3.9000314e-05%) - largest zero change 4.9878724e-05
# 0  Obj 0 Primal inf 1.2689035 (2)
# 3  Obj 0.98552402
# Optimal - objective value 0.98552268
# Optimal objective 0.9855226807 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/93ae25618c3841e7b0d7543f7487a05d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/93ae25618c3841e7b0d7543f7487a05d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 135.71562 - largest nonzero change 5.2929517e-05 ( 3.9000314e-05%) - largest zero change 4.9878724e-05
# 0  Obj 0 Primal inf 1.2476634 (2)
# 3  Obj 1.0000014
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6cf35d8601ea459ab7233ed3d6a43c5b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/6cf35d8601ea459ab7233ed3d6a43c5b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 135.71562 - largest nonzero change 5.2929517e-05 ( 3.9000314e-05%) - largest zero change 4.9878724e-05
# 0  Obj 0 Primal inf 1.2788213 (2)
# 3  Obj 0.97549451
# Optimal - objective value 0.97549319
# Optimal objective 0.9754931901 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/840e4f1446964feb8371f40f099a15bc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/840e4f1446964feb8371f40f099a15bc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 131.92951 - largest nonzero change 5.1462748e-05 ( 3.9007761e-05%) - largest zero change 4.8582732e-05
# 0  Obj 0 Primal inf 0.61343819 (2)
# 3  Obj 1.000001
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5980d2ecde7940e7a5407ed7fa4dd6f3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5980d2ecde7940e7a5407ed7fa4dd6f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 19.908335 - largest nonzero change 8.0648391e-05 ( 0.00040509862%) - largest zero change 2.8583782e-05
# 0  Obj 0 Primal inf 0.040609943 (2)
# 5  Obj 0.013181534
# Optimal - objective value 0.013181408
# Optimal objective 0.01318140784 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/118bb54c1c184190ae84a23abf8863fe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/118bb54c1c184190ae84a23abf8863fe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 35.549619 - largest nonzero change 1.4124399e-05 ( 3.9731506e-05%) - largest zero change 1.2476333e-05
# 0  Obj 0 Primal inf 0.25665356 (2)
# 4  Obj 0.11205684
# Optimal - objective value 0.11205661
# Optimal objective 0.1120566066 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cf3edcf1801f473cbc8d748808f8866e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cf3edcf1801f473cbc8d748808f8866e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 108.92047 - largest nonzero change 4.2548859e-05 ( 3.9064154e-05%) - largest zero change 4.2332521e-05
# 0  Obj 0 Primal inf 0.27551933 (2)
# 6  Obj 1.0000009
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/089947c354f541e9a762c33c25fd4f73-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/089947c354f541e9a762c33c25fd4f73-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 37.075328 - largest nonzero change 1.4715471e-05 ( 3.9690737e-05%) - largest zero change 1.2894234e-05
# 0  Obj 0 Primal inf 0.11412926 (2)
# 6  Obj 0.067712824
# Optimal - objective value 0.067712712
# Optimal objective 0.06771271175 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/98e9ad455daf417f93b917dd5d4de6d4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/98e9ad455daf417f93b917dd5d4de6d4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 44.798611 - largest nonzero change 1.7707533e-05 ( 3.9526969e-05%) - largest zero change 1.7544808e-05
# 0  Obj 0 Primal inf 0.13556009 (2)
# 4  Obj 0.1535535
# Optimal - objective value 0.15355332
# Optimal objective 0.1535533246 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/859e98cabe6c4e57b6916a9dc95ee1a7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/859e98cabe6c4e57b6916a9dc95ee1a7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 17.243602 - largest nonzero change 7.0325001e-05 ( 0.00040783242%) - largest zero change 2.6037062e-05
# 0  Obj 0 Primal inf 0.04390005 (2)
# 5  Obj 0.014975075
# Optimal - objective value 0.014974943
# Optimal objective 0.01497494285 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3a7f63285a4d44e58b92f000d0fb6ff0-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3a7f63285a4d44e58b92f000d0fb6ff0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 47.128138 - largest nonzero change 1.8610011e-05 ( 3.948811e-05%) - largest zero change 1.829065e-05
# 0  Obj 0 Primal inf 0.14809216 (2)
# 4  Obj 0.10662545
# Optimal - objective value 0.10662527
# Optimal objective 0.1066252732 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2b1b21bfcaaf4c18a57450cc42625a6d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2b1b21bfcaaf4c18a57450cc42625a6d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 11.842294 - largest nonzero change 4.9399896e-05 ( 0.00041714803%) - largest zero change 2.0874962e-05
# 0  Obj 0 Primal inf 0.617327 (2)
# 4  Obj 0.10225795
# Optimal - objective value 0.10225664
# Optimal objective 0.1022566402 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4648e209631548f6841fa8755b1c71ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4648e209631548f6841fa8755b1c71ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 46.998788 - largest nonzero change 1.8559899e-05 ( 3.9490166e-05%) - largest zero change 1.8249236e-05
# 0  Obj 0 Primal inf 0.18042516 (2)
# 4  Obj 0.27271539
# Optimal - objective value 0.27271512
# Optimal objective 0.27271512 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2cf40955cede4c6e9765e7a8185e0dbf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2cf40955cede4c6e9765e7a8185e0dbf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 31 (0) columns and 122 (0) elements
# Perturbing problem by 0.001% of 34.921478 - largest nonzero change 1.3881052e-05 ( 3.9749326e-05%) - largest zero change 1.2304281e-05
# 0  Obj 0 Primal inf 0.28193749 (2)
# 4  Obj 0.12068618
# Optimal - objective value 0.12068593
# Optimal objective 0.1206859289 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
df_2022[['Hub Airport','Airline', 'Airport_Efficiency', 'Airline_Efficiency','Overall_Efficiency']]
# Out:
#                                          Hub Airport               Airline  \
# 0               Chicago Midway International Airport    SouthWest Airlines
# 1   Hartsfield-Jackson Atlanta International Airport    SouthWest Airlines
# 2                       Denver International Airport     Frontier Airlines
# 3              Dallas/Ft Worth International Airport     Frontier Airlines
# 4       Minneapolis-Saint Paul International Airport  Sun Country Airlines
# 5                                    Abudabi Airport            Air Arabia
# 6              John F. Kennedy International Airport       JetBlue Airways
# 7                            Ankara Esenboga Airport           Anadolu Jet
# 8                            Ankara Esenboga Airport      Pegasus Airlines
# 9                                 Dusseldorf Airport             Eurowings
# 10               Indira Gandhi International Airport                IndiGo
# 11               Indira Gandhi International Airport              SpiceJet
# 12                                    Geneva Airport               EasyJet
# 13                                    Dublin Airport               Ryanair
# 14                     Incheon International Airport             Air Seoul
# 15                     Incheon International Airport             Air Busan
# 16                     Incheon International Airport               Jin Air
# 17                     Incheon International Airport              Jeju Air
# 18                     Incheon International Airport        T'way Airlines
# 19                      Narita International Airport         Jetstar Japan
# 20                                    Changi Airport                 Scoot
# 21       Budapest Ferenc Liszt International Airport              Wizz Air
# 22                    HongKong International Airport            HK Express
# 23             Toronto Pearson International Airport               WestJet
# 24        Aeropuerto de Adolfo Suárez Madrid-Barajas            Air Europa
# 25                              Suvarnabhumi Airport          Thai AirAsia
# 26                                 Melbourne Airport     Jetstar Australia
# 27   Fort Lauderdale-Hollywood International Airport        Spirit Airline
# 28                            Aéroport de Paris-Orly      Transavia France
# 29            The Ninoy Aquino International Airport      Cebu Pacific Air
#
#     Airport_Efficiency  Airline_Efficiency  Overall_Efficiency
# 0             1.000000            0.148616            0.148616
# 1             0.574333            0.258762            0.148616
# 2             0.696795            0.013584            0.009465
# 3             0.344595            0.027468            0.009465
# 4             0.296529            0.043078            0.012774
# 5             0.366179            0.026926            0.009860
# 6             0.070238            0.735790            0.051680
# 7             0.179593            0.299420            0.053774
# 8             0.240897            0.174027            0.041923
# 9             0.159516            0.136780            0.021819
# 10            0.146488            0.485717            0.071152
# 11            0.146488            0.186253            0.027284
# 12            1.000000            0.043338            0.043338
# 13            1.000000            0.078781            0.078781
# 14            0.087258            1.000000            0.087258
# 15            0.087258            1.000000            0.087258
# 16            0.087258            0.985523            0.085995
# 17            0.087258            1.000000            0.087258
# 18            0.087258            0.975493            0.085120
# 19            0.089762            1.000000            0.089762
# 20            0.384532            0.013181            0.005069
# 21            0.333120            0.112057            0.037328
# 22            0.108724            1.000000            0.108724
# 23            0.319412            0.067713            0.021628
# 24            0.123612            0.153553            0.018981
# 25            0.353099            0.014975            0.005288
# 26            0.196550            0.106625            0.020957
# 27            1.000000            0.102257            0.102257
# 28            0.094060            0.272715            0.025652
# 29            0.339112            0.120686            0.040926

# %%
# Define a function to calculate the Malmquist index
def malmquist_index(inputs_t1, outputs_t1, inputs_t2, outputs_t2):
    # Calculate efficiency scores inside each stage
    eff_t1 = calculate_efficiency(inputs_t1, outputs_t1)
    eff_t2 = calculate_efficiency(inputs_t2, outputs_t2)

    # Calculate efficiency scores between stages
    eff_t1_t2 = calculate_efficiency(inputs_t1, outputs_t2)
    eff_t2_t1 = calculate_efficiency(inputs_t2, outputs_t1)

    # Calculate efficiency change and technology change
    EC = eff_t2 / eff_t1
    TC = np.sqrt((eff_t1_t2 / eff_t2) * (eff_t1 / eff_t2_t1))
    # Calulate Malmquist index
    MI = EC * TC
    return MI, EC, TC

# %%
# Generate the inputs
inputs_2022_1 = df_2022[['operating_expense', 'Terminal_Size']]
inputs_2023_1 = df_2023[['operating_expense', 'Terminal_Size']]
outputs_2022_1 = df_2022[['Total_Aircraft_Movements','Total_Passenger_Traffic']]
outputs_2023_1 = df_2023[['Total_Aircraft_Movements','Total_Passenger_Traffic']]
inputs_2022_2 = df_2022[['Total_Aircraft_Movements','Total_Passenger_Traffic','Operation_Cost']]
inputs_2023_2 = df_2023[['Total_Aircraft_Movements','Total_Passenger_Traffic','Operation_Cost']]
outputs_2022_2 = df_2022[['Airline_CPE', 'On_Time_Performance_Rate']]
outputs_2023_2 = df_2023[['Airline_CPE', 'On_Time_Performance_Rate']]

# Convert the dataframes to numpy arrays
inputs_2022_1 = inputs_2022_1.to_numpy()
inputs_2023_1 = inputs_2023_1.to_numpy()
inputs_2022_2 = inputs_2022_2.to_numpy()
inputs_2023_2 = inputs_2023_2.to_numpy()
outputs_2022_1 = outputs_2022_1.to_numpy()
outputs_2023_1 = outputs_2023_1.to_numpy()
outputs_2022_2 = outputs_2022_2.to_numpy()
outputs_2023_2 = outputs_2023_2.to_numpy()


# Calculate the Malmquist index
MI_Stage1, EC_Stage1, TC_Stage1 = malmquist_index(inputs_2022_1, outputs_2022_1, inputs_2023_1, outputs_2023_1)

print("Malmquist Index (MI):", MI_Stage1)
print("Efficiency Change (EC):", EC_Stage1)
print("Technological Change (TC):", TC_Stage1)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c82cdd6e13644902b242b4fa2a94ca27-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c82cdd6e13644902b242b4fa2a94ca27-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3049976 (2)
# 4  Obj 0.62608969
# Optimal - objective value 0.62608969
# After Postsolve, objective 0.62608969, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.6260896853 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c89a7409699640c5b6978d6ca7727428-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c89a7409699640c5b6978d6ca7727428-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.1037953 (2)
# 3  Obj 0.58579801
# Optimal - objective value 0.58579801
# After Postsolve, objective 0.58579801, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5857980147 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/73ed2b00beef4223ae0bb323b3c9c7bf-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/73ed2b00beef4223ae0bb323b3c9c7bf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 3.717479 (2)
# 2  Obj 0.69679549
# Optimal - objective value 0.69679549
# After Postsolve, objective 0.69679549, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.6967954865 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/59528013d49a48a480c0f789c9dc670c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/59528013d49a48a480c0f789c9dc670c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.1306757 (2)
# 2  Obj 0.34459536
# Optimal - objective value 0.34459536
# After Postsolve, objective 0.34459536, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3445953585 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c3902a657216409f8803154743cb8f6f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c3902a657216409f8803154743cb8f6f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.5515137 (2)
# 3  Obj 0.41354567
# Optimal - objective value 0.41354567
# After Postsolve, objective 0.41354567, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4135456706 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dea475a6c310467e8ddd1875d4d068b8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dea475a6c310467e8ddd1875d4d068b8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.6227199 (2)
# 4  Obj 0.41409096
# Optimal - objective value 0.41409096
# After Postsolve, objective 0.41409096, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4140909591 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3be4aae01305421b88cfbad63796c70f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3be4aae01305421b88cfbad63796c70f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 3.0005301 (2)
# 4  Obj 0.1131509
# Optimal - objective value 0.1131509
# After Postsolve, objective 0.1131509, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1131508998 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e72b1fbc368a4bf2bdbc26a7788154c4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e72b1fbc368a4bf2bdbc26a7788154c4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.58764526 (2)
# 4  Obj 0.26451387
# Optimal - objective value 0.26451387
# After Postsolve, objective 0.26451387, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2645138662 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5991ef60ad1e4dc2b9c81dafc0648b80-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5991ef60ad1e4dc2b9c81dafc0648b80-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.58764526 (2)
# 4  Obj 0.26451387
# Optimal - objective value 0.26451387
# After Postsolve, objective 0.26451387, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2645138662 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a130c9b7975140049871a24565c42f1b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a130c9b7975140049871a24565c42f1b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.1923748 (2)
# 5  Obj 0.24002082
# Optimal - objective value 0.24002082
# After Postsolve, objective 0.24002082, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2400208174 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0db4d061edf24d4bbc8f0267bb0e981d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0db4d061edf24d4bbc8f0267bb0e981d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-2) rows, 24 (-7) columns and 48 (-74) elements
# 0  Obj 0 Primal inf 1.5749634 (2)
# 1  Obj 0.40886542
# Optimal - objective value 0.40886542
# After Postsolve, objective 0.40886542, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4088654224 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/92a6125b50ea4a548a89557a35b9cd95-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/92a6125b50ea4a548a89557a35b9cd95-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 2 (-2) rows, 24 (-7) columns and 48 (-74) elements
# 0  Obj 0 Primal inf 1.5749634 (2)
# 1  Obj 0.40886542
# Optimal - objective value 0.40886542
# After Postsolve, objective 0.40886542, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4088654224 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/072da8fe71e14ba48b9ddcab832b5dd4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/072da8fe71e14ba48b9ddcab832b5dd4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-4) rows, 0 (-31) columns and 0 (-122) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bf0fb8e6322a4ed3996255b834fd19a6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bf0fb8e6322a4ed3996255b834fd19a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.70614546 (2)
# 3  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c2902ef339004b6aa6f00d68ab2164fd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c2902ef339004b6aa6f00d68ab2164fd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a17b599d75344cfe99773aadd2ccacd6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a17b599d75344cfe99773aadd2ccacd6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/69d39f61c70548a580ee006d619e3cf8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/69d39f61c70548a580ee006d619e3cf8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3c07ab76b43c443eb8d8e9c896e02933-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3c07ab76b43c443eb8d8e9c896e02933-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/32960dea98b0405ab99065000b8f41de-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/32960dea98b0405ab99065000b8f41de-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5724169 (2)
# 3  Obj 0.12826441
# Optimal - objective value 0.12826441
# After Postsolve, objective 0.12826441, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1282644125 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7062e297817f4eeb88ce738ee89538e9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7062e297817f4eeb88ce738ee89538e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 72 (-50) elements
# 0  Obj 0 Primal inf 1.1680974 (2)
# 3  Obj 0.23086036
# Optimal - objective value 0.23086036
# After Postsolve, objective 0.23086036, infeasibilities - dual 0.36513353 (3), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 0.23086036 Dual inf 0.28360803 (3)
# 4  Obj 0.16055146
# Optimal - objective value 0.16055146
# Optimal objective 0.1605514609 - 7 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3042f9b18a3a4a4eb5a88154b0d55e6e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3042f9b18a3a4a4eb5a88154b0d55e6e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.2388755 (2)
# 1  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5b0bbf0af0a24b3ab1868308312d0eae-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5b0bbf0af0a24b3ab1868308312d0eae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.0570762 (2)
# 3  Obj 0.4345698
# Optimal - objective value 0.4345698
# After Postsolve, objective 0.4345698, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4345698024 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fab9f6147926421597a45c023cb947e9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fab9f6147926421597a45c023cb947e9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.2241094 (2)
# 3  Obj 0.13255423
# Optimal - objective value 0.13255423
# After Postsolve, objective 0.13255423, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1325542291 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bab5e0dffbbe4aeabf28cac9245a1781-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bab5e0dffbbe4aeabf28cac9245a1781-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.2672313 (2)
# 4  Obj 0.47253023
# Optimal - objective value 0.47253023
# After Postsolve, objective 0.47253023, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.4725302326 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b22fee62eed8461a98ed50f91eb3068d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b22fee62eed8461a98ed50f91eb3068d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.7249645 (2)
# 2  Obj 0.32691392
# Optimal - objective value 0.32691392
# After Postsolve, objective 0.32691392, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.326913918 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/976aa8c5f16b4410819f53850e495a04-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/976aa8c5f16b4410819f53850e495a04-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.7514044 (2)
# 4  Obj 0.62193244
# Optimal - objective value 0.62193244
# After Postsolve, objective 0.62193244, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.6219324415 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/73ae592765e44040b780217581603665-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/73ae592765e44040b780217581603665-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 72 (-50) elements
# 0  Obj 0 Primal inf 1.424238 (2)
# 2  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0.99045599 (2), primal 0 (0)
# Presolved model was optimal, full model needs cleaning up
# 0  Obj 1 Dual inf 0.70611094 (2)
# 1  Obj 0.94500777
# Optimal - objective value 0.94500777
# Optimal objective 0.9450077713 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5128c94030744d4aaabea96abb116850-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5128c94030744d4aaabea96abb116850-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.2459256 (2)
# 1  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/06419437310c429282a73f82fc5c0165-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/06419437310c429282a73f82fc5c0165-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.1631671 (2)
# 5  Obj 0.18893055
# Optimal - objective value 0.18893055
# After Postsolve, objective 0.18893055, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1889305533 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/69e8e70e779e4c8c92fd346f323c4d83-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/69e8e70e779e4c8c92fd346f323c4d83-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.8104068 (2)
# 5  Obj 0.54932843
# Optimal - objective value 0.54932843
# After Postsolve, objective 0.54932843, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5493284321 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8d73cd1d21af478fb5f55de20298379a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8d73cd1d21af478fb5f55de20298379a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.7724352 (2)
# 4  Obj 0.5100765
# Optimal - objective value 0.5100765
# After Postsolve, objective 0.5100765, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5100764982 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/29101b073a324314924f82321b58d30d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/29101b073a324314924f82321b58d30d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 5.7680825 (2)
# 4  Obj 0.67930393
# Optimal - objective value 0.67930393
# After Postsolve, objective 0.67930393, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.679303932 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/62231119641b48f5b2bc42e71d8c52a8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/62231119641b48f5b2bc42e71d8c52a8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.5832375 (2)
# 4  Obj 0.90118036
# Optimal - objective value 0.90118036
# After Postsolve, objective 0.90118036, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.9011803615 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dacc37ed0dde47ab98fae1e232644897-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dacc37ed0dde47ab98fae1e232644897-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 5.0720532 (2)
# 3  Obj 0.38167765
# Optimal - objective value 0.38167765
# After Postsolve, objective 0.38167765, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3816776525 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/077d2b4fbef040869f82769c8876fb71-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/077d2b4fbef040869f82769c8876fb71-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.90530174 (2)
# 4  Obj 0.3944011
# Optimal - objective value 0.3944011
# After Postsolve, objective 0.3944011, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3944011007 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2e6fd4cd6f8642b38629ecbbf4490b3f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2e6fd4cd6f8642b38629ecbbf4490b3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 3.9111817 (2)
# 3  Obj 0.7081506
# Optimal - objective value 0.7081506
# After Postsolve, objective 0.7081506, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.7081505982 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9b4a4a6010454274b6ae2a016a46619b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9b4a4a6010454274b6ae2a016a46619b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3525575 (2)
# 3  Obj 0.16947017
# Optimal - objective value 0.16947017
# After Postsolve, objective 0.16947017, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1694701693 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f4ad27b6890a4c708183749237d16d4c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f4ad27b6890a4c708183749237d16d4c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.99126312 (2)
# 4  Obj 0.27586212
# Optimal - objective value 0.27586212
# After Postsolve, objective 0.27586212, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2758621204 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1b54396921e84258a0e46bfc8d1e837b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1b54396921e84258a0e46bfc8d1e837b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.99126312 (2)
# 4  Obj 0.27586212
# Optimal - objective value 0.27586212
# After Postsolve, objective 0.27586212, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2758621204 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9e0eed6e1b984c99ad71a034ddecc5d3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9e0eed6e1b984c99ad71a034ddecc5d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.46206499 (2)
# 3  Obj 0.22390942
# Optimal - objective value 0.22390942
# After Postsolve, objective 0.22390942, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.2239094222 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/221513cefcb24509a3f89aafe5ce9d33-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/221513cefcb24509a3f89aafe5ce9d33-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5740832 (2)
# 2  Obj 0.32165954
# Optimal - objective value 0.32165954
# After Postsolve, objective 0.32165954, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3216595437 - 2 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1002ed3a1d27489ca601650fac206316-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/1002ed3a1d27489ca601650fac206316-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.5740832 (2)
# 2  Obj 0.32165954
# Optimal - objective value 0.32165954
# After Postsolve, objective 0.32165954, infeasibilities - dual 0 (0), primal 0 (0)
# ...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f268c168c2a14e4bb0b1de756907a7db-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f268c168c2a14e4bb0b1de756907a7db-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3008908 (2)
# 4  Obj 0.12629552
# Optimal - objective value 0.12629552
# After Postsolve, objective 0.12629552, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1262955165 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/59232d8a1230426ea25ef35902bb73e1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/59232d8a1230426ea25ef35902bb73e1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.3008908 (2)
# 4  Obj 0.12629552
# Optimal - objective value 0.12629552
# After Postsolve, objective 0.12629552, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1262955165 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9bd6fa52d1d24b3b920214841cb65c09-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9bd6fa52d1d24b3b920214841cb65c09-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.90969707 (2)
# 5  Obj 0.10745086
# Optimal - objective value 0.10745086
# After Postsolve, objective 0.10745086, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1074508593 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7163e546e0e04975bda91c81c2190911-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7163e546e0e04975bda91c81c2190911-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 4 (0) rows, 25 (-6) columns and 98 (-24) elements
# Perturbing problem by 0.001% of 0.39528985 - largest nonzero change 3.999674e-05 ( 0.010118332%) - largest zero change 3.994787e-05
# 0  Obj 0 Primal inf 2.528675 (2)
# 8  Obj 1.0001597
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 8 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/392fc6e9c1ec4c88aa02817262e12c47-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/392fc6e9c1ec4c88aa02817262e12c47-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.0351621 (2)
# 3  Obj 0.36674562
# Optimal - objective value 0.36674562
# After Postsolve, objective 0.36674562, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3667456224 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/22ef6b7ec7e646018a11659902876919-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/22ef6b7ec7e646018a11659902876919-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.0090286 (2)
# 3  Obj 0.13250237
# Optimal - objective value 0.13250237
# After Postsolve, objective 0.13250237, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1325023733 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/00b4c9ea2c22430dbd0821a292a7f46a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/00b4c9ea2c22430dbd0821a292a7f46a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.5117002 (2)
# 4  Obj 0.35495081
# Optimal - objective value 0.35495081
# After Postsolve, objective 0.35495081, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.3549508121 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/925c2bba962143cbbbd2773047a34942-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/925c2bba962143cbbbd2773047a34942-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 4.7323956 (2)
# 3  Obj 0.33351534
# Optimal - objective value 0.33351534
# After Postsolve, objective 0.33351534, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.333515337 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e9f7a238db44452fa4848211b5f97231-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e9f7a238db44452fa4848211b5f97231-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.129983 (2)
# 5  Obj 0.58515378
# Optimal - objective value 0.58515378
# After Postsolve, objective 0.58515378, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5851537809 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/98832f434dfd4844abc75a80c31fa8cd-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/98832f434dfd4844abc75a80c31fa8cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 1.296018 (2)
# 3  Obj 0.75752825
# Optimal - objective value 0.75752825
# After Postsolve, objective 0.75752825, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.7575282528 - 3 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c85a8bcf51154b309e2de7d9105b613a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/c85a8bcf51154b309e2de7d9105b613a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.4136542 (2)
# 1  Obj 1
# Optimal - objective value 1
# After Postsolve, objective 1, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 1 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fb11cab3a06a4338902f04b1e30efee5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/fb11cab3a06a4338902f04b1e30efee5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 2.1754333 (2)
# 4  Obj 0.16962423
# Optimal - objective value 0.16962423
# After Postsolve, objective 0.16962423, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.1696242312 - 4 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88bebb1cfbe14c49a6495b181984eb21-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/88bebb1cfbe14c49a6495b181984eb21-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 9 COLUMNS
# At line 133 RHS
# At line 138 BOUNDS
# At line 139 ENDATA
# Problem MODEL has 4 rows, 31 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (-1) rows, 24 (-7) columns and 71 (-51) elements
# 0  Obj 0 Primal inf 0.8104068 (2)
# 5  Obj 0.50206271
# Optimal - objective value 0.50206271
# After Postsolve, objective 0.50206271, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 0.5020627091 - 5 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Malmquist Index (MI): [0.97708169 1.16529979 1.24393088 1.09127045 0.99288712 1.72079127
#  1.50476186 1.18249158 1.18249158 1.02512433 0.69287772 0.69287772
#  1.         1.         2.59384353 2.59384353 2.59384353 2.59384353
#  2.59384353 1.85773261 1.         1.13488173 2.67202132 1.07835464
#  0.90689543 1.57754284 1.05105871 1.         0.97046752 1.27392876]
# Efficiency Change (EC): [0.81470196 1.15962144 1.29332117 1.10761111 0.95370627 1.71013296
#  1.49773594 1.04290229 1.04290229 0.93287499 0.78671251 0.78671251
#  1.         1.         2.52315611 2.52315611 2.52315611 2.52315611
#  2.52315611 1.24229297 1.         0.95588978 2.58101827 0.80320032
#  1.00022039 1.48077119 0.84063615 1.         0.87168978 1.16513221]
# Technological Change (TC): [1.19931182 1.00489673 0.96181127 0.98524694 1.04108272 1.00623244
#  1.00469102 1.13384695 1.13384695 1.09888714 0.88072544 0.88072544
#  1.         1.         1.02801548 1.02801548 1.02801548 1.02801548
#  1.02801548 1.4954062  1.         1.18725166 1.03525858 1.34257248
#  0.9066956  1.0653522  1.25031349 1.         1.11331754 1.093377  ]

# %%
MI_Stage2, EC_Stage2, TC_Stage2 = malmquist_index(inputs_2022_2, outputs_2022_2, inputs_2023_2, outputs_2023_2)

print("Malmquist Index (MI):", MI_Stage2)
print("Efficiency Change (EC):", EC_Stage2)
print("Technological Change (TC):", TC_Stage2)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ca76010bc9b64be2a69c706522d3ae76-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ca76010bc9b64be2a69c706522d3ae76-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 38.718421 - largest nonzero change 3.0704037e-05 ( 7.930085e-05%) - largest zero change 2.3280412e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 7  Obj 1.0000026
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b42c0ec7ab7149adaf0d1ae2c960ed1d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b42c0ec7ab7149adaf0d1ae2c960ed1d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 1.0072867 (2)
# 7  Obj 0.51096647
# Optimal - objective value 0.51095467
# Optimal objective 0.5109546708 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3416b219564c43c085cee6458b3273cb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3416b219564c43c085cee6458b3273cb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 12.237064 - largest nonzero change 1.0185854e-05 ( 8.3237722e-05%) - largest zero change 1.0133002e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 6  Obj 0.037853704
# Optimal - objective value 0.037853639
# Optimal objective 0.03785363949 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e56bec93935f4bc5baacc63ee12d0901-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e56bec93935f4bc5baacc63ee12d0901-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 12.237064 - largest nonzero change 1.0185854e-05 ( 8.3237722e-05%) - largest zero change 1.0133002e-05
# 0  Obj 0 Primal inf 0.069747951 (2)
# 6  Obj 0.040349717
# Optimal - objective value 0.04034965
# Optimal objective 0.04034965025 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/309f1c7954944a3fa677034765e75ac1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/309f1c7954944a3fa677034765e75ac1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 0.093189587 (2)
# 9  Obj 0.056420989
# Optimal - objective value 0.056419821
# Optimal objective 0.05641982144 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/60309e3886174f0490e6e8ec3211b9d9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/60309e3886174f0490e6e8ec3211b9d9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 25.302864 - largest nonzero change 2.0309446e-05 ( 8.0265406e-05%) - largest zero change 1.6869701e-05
# 0  Obj 0 Primal inf 0.073745763 (2)
# 8  Obj 0.11053294
# Optimal - objective value 0.11053277
# Optimal objective 0.1105327668 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dce86eac2b2a48898994669d710e1289-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/dce86eac2b2a48898994669d710e1289-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 23.674264 - largest nonzero change 1.9047581e-05 ( 8.0456908e-05%) - largest zero change 1.6091465e-05
# 0  Obj 0 Primal inf 0.35428912 (2)
# 7  Obj 0.23826101
# Optimal - objective value 0.23826041
# Optimal objective 0.2382604085 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5e4d812270b34659ab67925454bf0b0a-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5e4d812270b34659ab67925454bf0b0a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 88.84528 - largest nonzero change 6.9543138e-05 ( 7.8274431e-05%) - largest zero change 4.7233855e-05
# 0  Obj 0 Primal inf 0.36779419 (2)
# 8  Obj 0.87136038
# Optimal - objective value 0.87135841
# Optimal objective 0.8713584115 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b007a4e4c1504d64b0ff3e89416f8afe-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/b007a4e4c1504d64b0ff3e89416f8afe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 51.94707 - largest nonzero change 4.0953808e-05 ( 7.8837571e-05%) - largest zero change 2.9601807e-05
# 0  Obj 0 Primal inf 0.28946828 (2)
# 9  Obj 0.65240424
# Optimal - objective value 0.65240309
# Optimal objective 0.6524030872 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9802ea53a4b047fc8652e863a96fac10-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/9802ea53a4b047fc8652e863a96fac10-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 42.827984 - largest nonzero change 3.3888193e-05 ( 7.9126285e-05%) - largest zero change 2.5244193e-05
# 0  Obj 0 Primal inf 0.15566439 (2)
# 9  Obj 0.18537711
# Optimal - objective value 0.18537668
# Optimal objective 0.1853766775 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/020be61534bc4e8691e30c9d99edf3e3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/020be61534bc4e8691e30c9d99edf3e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 0.48737441 (2)
# 9  Obj 0.21076087
# Optimal - objective value 0.21075555
# Optimal objective 0.2107555468 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0281be25c17b4203b37ee42d51a8dd2e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0281be25c17b4203b37ee42d51a8dd2e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 11.714601 - largest nonzero change 9.7810408e-05 ( 0.00083494441%) - largest zero change 9.7314293e-05
# 0  Obj 0 Primal inf 0.19095358 (2)
# 9  Obj 0.083853852
# Optimal - objective value 0.083851793
# Optimal objective 0.08385179305 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/659cb8ed83f048bba3cf5384ab3175c3-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/659cb8ed83f048bba3cf5384ab3175c3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 20.77514 - largest nonzero change 1.6801293e-05 ( 8.0872103e-05%) - largest zero change 1.4706099e-05
# 0  Obj 0 Primal inf 0.29833923 (2)
# 8  Obj 0.41511449
# Optimal - objective value 0.41511382
# Optimal objective 0.4151138235 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2cc0f5fbfa7349d38b089b18df006a9f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/2cc0f5fbfa7349d38b089b18df006a9f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 19.367854 - largest nonzero change 1.5710905e-05 ( 8.1118459e-05%) - largest zero change 1.4033618e-05
# 0  Obj 0 Primal inf 1.2641568 (2)
# 7  Obj 0.76250705
# Optimal - objective value 0.76250552
# Optimal objective 0.7625055241 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/564db52aa91d409fb7b5da18ba0fc0d1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/564db52aa91d409fb7b5da18ba0fc0d1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2427352 (2)
# 6  Obj 1.0000021
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/45304042a4d54b0ba7cb35c1c541c090-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/45304042a4d54b0ba7cb35c1c541c090-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.4159371 (2)
# 4  Obj 1.0000026
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/aa21bcc087dc413e9f9656967aa50429-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/aa21bcc087dc413e9f9656967aa50429-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2689035 (2)
# 5  Obj 0.98552523
# Optimal - objective value 0.98552268
# Optimal objective 0.9855226807 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/168e73c5d6c0470189a74ec9c4c54241-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/168e73c5d6c0470189a74ec9c4c54241-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2476634 (2)
# 4  Obj 1.0000026
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5a347c162d3e4780b046b042b6e7bf3e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/5a347c162d3e4780b046b042b6e7bf3e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 43.153406 - largest nonzero change 3.4140335e-05 ( 7.9113883e-05%) - largest zero change 2.5399698e-05
# 0  Obj 0 Primal inf 1.2788213 (2)
# 5  Obj 0.9754957
# Optimal - objective value 0.97549319
# Optimal objective 0.9754931901 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/aef4a27ba31b41e4bccdace3f1af4864-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/aef4a27ba31b41e4bccdace3f1af4864-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 50.022364 - largest nonzero change 3.9462515e-05 ( 7.8889744e-05%) - largest zero change 2.8682074e-05
# 0  Obj 0 Primal inf 0.61343819 (2)
# 7  Obj 1.000002
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/620a56f719b443c28b348187d3cb7a34-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/620a56f719b443c28b348187d3cb7a34-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 19.693668 - largest nonzero change 1.5963351e-05 ( 8.1058291e-05%) - largest zero change 1.4189311e-05
# 0  Obj 0 Primal inf 0.040609943 (2)
# 7  Obj 0.027707243
# Optimal - objective value 0.027707181
# Optimal objective 0.02770718144 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0663096c7ba74cd6b5b8360c66108835-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0663096c7ba74cd6b5b8360c66108835-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 46.025102 - largest nonzero change 3.6365372e-05 ( 7.9012039e-05%) - largest zero change 2.6771957e-05
# 0  Obj 0 Primal inf 0.25665356 (2)
# 9  Obj 0.41244129
# Optimal - objective value 0.41244046
# Optimal objective 0.4124404563 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/10b0a56709cc499db26e2fe41088cafb-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/10b0a56709cc499db26e2fe41088cafb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 52.78905 - largest nonzero change 4.1606187e-05 ( 7.8815943e-05%) - largest zero change 3.0004152e-05
# 0  Obj 0 Primal inf 0.27551933 (2)
# 8  Obj 1.0000013
# Optimal - objective value 1
# Optimal objective 1 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f3ed2f4588194c0e8a4e5de9a30f40c7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/f3ed2f4588194c0e8a4e5de9a30f40c7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 21.661263 - largest nonzero change 1.7487875e-05 ( 8.0733405e-05%) - largest zero change 1.5129539e-05
# 0  Obj 0 Primal inf 0.11412926 (2)
# 7  Obj 0.078236591
# Optimal - objective value 0.078236411
# Optimal objective 0.07823641108 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ee0d6fed956c460caa4ae55c61fa7189-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ee0d6fed956c460caa4ae55c61fa7189-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 15.23994 - largest nonzero change 1.251253e-05 ( 8.210354e-05%) - largest zero change 1.2337755e-05
# 0  Obj 0 Primal inf 0.13556009 (2)
# 5  Obj 0.066330597
# Optimal - objective value 0.066330413
# Optimal objective 0.06633041327 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/19dd948e939f4c5a9b7958f4e2e66655-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/19dd948e939f4c5a9b7958f4e2e66655-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 17.057668 - largest nonzero change 1.3920936e-05 ( 8.1611011e-05%) - largest zero change 1.2929681e-05
# 0  Obj 0 Primal inf 0.04390005 (2)
# 9  Obj 0.029246332
# Optimal - objective value 0.02924627
# Optimal objective 0.02924626987 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e81e25796bcc4f69ad91ec1cb9e9182c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e81e25796bcc4f69ad91ec1cb9e9182c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 30.016167 - largest nonzero change 2.396139e-05 ( 7.982828e-05%) - largest zero change 1.9121984e-05
# 0  Obj 0 Primal inf 0.14809216 (2)
# 10  Obj 0.40792771
# Optimal - objective value 0.40792718
# Optimal objective 0.407927177 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/acb673958dbd465398b06c7702f59400-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/acb673958dbd465398b06c7702f59400-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 29.846106 - largest nonzero change 2.3829624e-05 ( 7.9841651e-05%) - largest zero change 1.9040719e-05
# 0  Obj 0 Primal inf 0.617327 (2)
# 8  Obj 0.86081313
# Optimal - objective value 0.86081158
# Optimal objective 0.8608115835 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a891aab241fa4e9ca5d0eae1eb1e57b1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/a891aab241fa4e9ca5d0eae1eb1e57b1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 26.420456 - largest nonzero change 2.1175375e-05 ( 8.0147651e-05%) - largest zero change 1.740375e-05
# 0  Obj 0 Primal inf 0.18042516 (2)
# 8  Obj 0.15182439
# Optimal - objective value 0.15182404
# Optimal objective 0.1518240381 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ef8499921f5459ea6f9f8e6ff285b31-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ef8499921f5459ea6f9f8e6ff285b31-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 24.906474 - largest nonzero change 2.0002317e-05 ( 8.030971e-05%) - largest zero change 1.6680284e-05
# 0  Obj 0 Primal inf 0.28193749 (2)
# 7  Obj 0.21408143
# Optimal - objective value 0.21408093
# Optimal objective 0.2140809318 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d1bf7c608a7f4d14a9eb8b54ce2d87c8-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/d1bf7c608a7f4d14a9eb8b54ce2d87c8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.0954487 - largest nonzero change 3.1027821e-05 ( 0.0010023691%) - largest zero change 3.0187112e-05
# 0  Obj 0 Primal inf 2.7378351 (2)
# 7  Obj 1.0000242
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cd11117abf1e4e2ba16397686a0b37ee-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/cd11117abf1e4e2ba16397686a0b37ee-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.8190225 - largest nonzero change 2.1137864e-05 ( 0.0011620452%) - largest zero change 2.1036287e-05
# 0  Obj 0 Primal inf 2.7378351 (2)
# 4  Obj 0.60312278
# Optimal - objective value 0.60310951
# Optimal objective 0.6031095051 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e6a0b5491b4d4bfb9fe37ec32713b19d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e6a0b5491b4d4bfb9fe37ec32713b19d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.3237893 - largest nonzero change 2.5048879e-05 ( 0.0010779324%) - largest zero change 2.4774527e-05
# 0  Obj 0 Primal inf 0.52342188 (2)
# 7  Obj 0.098566365
# Optimal - objective value 0.098563048
# Optimal objective 0.09856304808 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/eaa19b36c078436ca4cafac20fbbb409-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/eaa19b36c078436ca4cafac20fbbb409-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.3060188 - largest nonzero change 2.491119e-05 ( 0.0010802683%) - largest zero change 2.4738803e-05
# 0  Obj 0 Primal inf 0.52342188 (2)
# 6  Obj 0.10544785
# Optimal - objective value 0.10544451
# Optimal objective 0.1054445117 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7f96e6a838794f17b5fb74f569e5ec7c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/7f96e6a838794f17b5fb74f569e5ec7c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.5996168 - largest nonzero change 2.7186035e-05 ( 0.0010457708%) - largest zero change 2.6931903e-05
# 0  Obj 0 Primal inf 0.29747686 (2)
# 8  Obj 0.12057988
# Optimal - objective value 0.12057694
# Optimal objective 0.1205769427 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e1135bd2d92244e89739fbb64a687eb9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e1135bd2d92244e89739fbb64a687eb9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.0155201 - largest nonzero change 2.2660359e-05 ( 0.0011242934%) - largest zero change 2.1621247e-05
# 0  Obj 0 Primal inf 0.33265579 (2)
# 7  Obj 0.067461974
# Optimal - objective value 0.06746045
# Optimal objective 0.06746045039 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4bfea3a381f847d08f571862742e545b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/4bfea3a381f847d08f571862742e545b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.5972831 - largest nonzero change 1.9419791e-05 ( 0.0012158014%) - largest zero change 1.9053356e-05
# 0  Obj 0 Primal inf 0.99601372 (2)
# 5  Obj 0.23615211
# Optimal - objective value 0.23614686
# Optimal objective 0.2361468562 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/969877785ffe425d8944211ee5bec572-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/969877785ffe425d8944211ee5bec572-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 7.5868839 - largest nonzero change 6.5828187e-05 ( 0.00086765775%) - largest zero change 6.3293199e-05
# 0  Obj 0 Primal inf 1.388316 (2)
# 3  Obj 1.0000172
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ca9c72aa8ad24edc935378cc1198645e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ca9c72aa8ad24edc935378cc1198645e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.073858 - largest nonzero change 3.8608694e-05 ( 0.0009477182%) - largest zero change 3.8549199e-05
# 0  Obj 0 Primal inf 0.79526833 (2)
# 9  Obj 0.48738299
# Optimal - objective value 0.48737403
# Optimal objective 0.4873740281 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ddf14d47d7e34c488cf0fd8cd7c1aa6f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ddf14d47d7e34c488cf0fd8cd7c1aa6f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.3520421 - largest nonzero change 3.3015948e-05 ( 0.00098495026%) - largest zero change 3.1901798e-05
# 0  Obj 0 Primal inf 0.47298363 (2)
# 7  Obj 0.14098424
# Optimal - objective value 0.14098048
# Optimal objective 0.1409804837 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bf71a6f60d2c480cbeeaf71df90d68c6-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/bf71a6f60d2c480cbeeaf71df90d68c6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 1.2281353 - largest nonzero change 1.6559574e-05 ( 0.001348351%) - largest zero change 1.5377291e-05
# 0  Obj 0 Primal inf 1.2698509 (2)
# 10  Obj 0.22029041
# ...
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.1851052 - largest nonzero change 2.3974332e-05 ( 0.0010971706%) - largest zero change 2.382523e-05
# 0  Obj 0 Primal inf 13.812164 (2)
# 5  Obj 1.0000311
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/48e50c6e5af24b62860127f50d59cfd2-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/48e50c6e5af24b62860127f50d59cfd2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.1851052 - largest nonzero change 2.3974332e-05 ( 0.0010971706%) - largest zero change 2.382523e-05
# 0  Obj 0 Primal inf 13.608704 (2)
# 6  Obj 0.97006734
# Optimal - objective value 0.97003734
# Optimal objective 0.9700373433 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3032d171b8204b448080be58770d2e20-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/3032d171b8204b448080be58770d2e20-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.7505477 - largest nonzero change 3.6103633e-05 ( 0.00096262296%) - largest zero change 3.285394e-05
# 0  Obj 0 Primal inf 2.5645915 (2)
# 4  Obj 1.0000181
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/34ad7993f40d451ab3016bf7fd25f53f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/34ad7993f40d451ab3016bf7fd25f53f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.0826043 - largest nonzero change 2.3180138e-05 ( 0.0011130361%) - largest zero change 2.3156357e-05
# 0  Obj 0 Primal inf 0.23093838 (2)
# 7  Obj 0.033197723
# Optimal - objective value 0.033197023
# Optimal objective 0.0331970231 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0cd43e523a50419da959659d62dd7cd7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/0cd43e523a50419da959659d62dd7cd7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 4.4947921 - largest nonzero change 4.187016e-05 ( 0.00093152605%) - largest zero change 3.9702165e-05
# 0  Obj 0 Primal inf 1.0888739 (2)
# 7  Obj 0.35876413
# Optimal - objective value 0.3587567
# Optimal objective 0.3587566954 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/18bcdeb9ae4f4248a8629ae6efd086a4-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/18bcdeb9ae4f4248a8629ae6efd086a4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7138361 - largest nonzero change 2.8071024e-05 ( 0.001034367%) - largest zero change 2.7609785e-05
# 0  Obj 0 Primal inf 1.1951881 (2)
# 5  Obj 0.28389746
# Optimal - objective value 0.28389096
# Optimal objective 0.2838909645 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ef4943b6b914b73a65a4bce7c05765c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/8ef4943b6b914b73a65a4bce7c05765c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7380668 - largest nonzero change 2.8258768e-05 ( 0.0010320701%) - largest zero change 2.7662405e-05
# 0  Obj 0 Primal inf 0.51643295 (2)
# 5  Obj 0.12971431
# Optimal - objective value 0.12971141
# Optimal objective 0.1297114084 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ed55704c14c7417597c533eed7ab7064-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/ed55704c14c7417597c533eed7ab7064-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.0376311 - largest nonzero change 2.2831679e-05 ( 0.0011205011%) - largest zero change 2.2709388e-05
# 0  Obj 0 Primal inf 0.62658977 (2)
# 6  Obj 0.080897212
# Optimal - objective value 0.080895346
# Optimal objective 0.08089534637 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/63093886ec234f958626b381673fdd1e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/63093886ec234f958626b381673fdd1e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.3726793 - largest nonzero change 2.5427686e-05 ( 0.0010716866%) - largest zero change 2.5248477e-05
# 0  Obj 0 Primal inf 0.26306657 (2)
# 7  Obj 0.035770702
# Optimal - objective value 0.035769603
# Optimal objective 0.03576960274 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/34b39c4cc42c4af8b9332584f17e064b-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/34b39c4cc42c4af8b9332584f17e064b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7152956 - largest nonzero change 2.8082333e-05 ( 0.0010342275%) - largest zero change 2.7612954e-05
# 0  Obj 0 Primal inf 0.66901547 (2)
# 8  Obj 0.12423856
# Optimal - objective value 0.12423507
# Optimal objective 0.1242350662 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/936420580fa448b284f2a67b96f59979-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/936420580fa448b284f2a67b96f59979-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 6.6852811 - largest nonzero change 5.8842422e-05 ( 0.00088017873%) - largest zero change 5.7114024e-05
# 0  Obj 0 Primal inf 2.5687728 (2)
# 5  Obj 1.0000257
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/939e902335b04aba8fae18f480d9ce16-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/939e902335b04aba8fae18f480d9ce16-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 3.7983761 - largest nonzero change 3.6474216e-05 ( 0.00096025813%) - largest zero change 3.6468814e-05
# 0  Obj 0 Primal inf 0.80676614 (2)
# 6  Obj 0.17465974
# Optimal - objective value 0.17465521
# Optimal objective 0.1746552074 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e3785f3a68c44ce095c2c773791ab9d5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/qq/qm3gfqv10wlf0kzp_9ql0hsc0000gn/T/e3785f3a68c44ce095c2c773791ab9d5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 165 RHS
# At line 171 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 5 rows, 31 columns and 153 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 31 (0) columns and 153 (0) elements
# Perturbing problem by 0.001% of 2.7078688 - largest nonzero change 2.8024789e-05 ( 0.0010349389%) - largest zero change 2.7596826e-05
# 0  Obj 0 Primal inf 1.2017162 (2)
# 6  Obj 0.25022812
# Optimal - objective value 0.25022183
# Optimal objective 0.2502218275 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Malmquist Index (MI): [ 0.95267471  1.1082398   2.3805533   2.41092201  0.99870514  0.97388023
#   0.99631445  1.14684887  0.83055346  0.73132855  0.97697781  1.34994728
#   0.75912004  1.14519252  0.5028936   0.42697876  0.30036482  0.25268717
#   0.29530929  1.         13.08584765  1.75482257  0.87497851  2.29203961
#   0.9506707   8.59188411  0.64468401  0.87906667  0.88403013  1.1298012 ]
# Efficiency Change (EC): [ 1.          1.18035815  2.6037932   2.61326951  2.13713794  0.61032081
#   0.99112924  1.14763338  0.74704433  0.76050817  1.04521433  1.90200524
#   0.70532448  1.31146592  0.50274854  0.35295142  0.24606141  0.20408776
#   0.23311726  1.         19.65715531  1.62261506  0.21734334  3.89348969
#   1.15464802 12.32813689  0.20472941  1.16169441  1.01138423  1.29131997]
# Technological Change (TC): [0.95267471 0.93890129 0.91426358 0.92256922 0.46730963 1.59568575
#  1.00523161 0.99931641 1.11178604 0.96163141 0.93471529 0.70974951
#  1.07627065 0.87321562 1.00028854 1.20973806 1.22069047 1.23812997
#  1.2667843  1.         0.66570404 1.08147805 4.02578938 0.58868516
#  0.82334242 0.69693289 3.14895654 0.75671077 0.87407941 0.87491964]

# %%
Final_MI = MI_Stage1 * MI_Stage2
Final_MI
# Out:
# array([ 0.93084102,  1.2914316 ,  2.96124375,  2.63096796,  0.99160147,
#         1.67584459,  1.49921598,  1.35613913,  0.98212248,  0.74970269,
#         0.67692616,  0.9353484 ,  0.75912004,  1.14519252,  1.30442732,
#         1.10751611,  0.77909934,  0.65543099,  0.76598608,  1.85773261,
#        13.08584765,  1.99151607,  2.33796124,  2.47163154,  0.86215891,
#        13.5540653 ,  0.67760075,  0.87906667,  0.85792253,  1.43928625])
